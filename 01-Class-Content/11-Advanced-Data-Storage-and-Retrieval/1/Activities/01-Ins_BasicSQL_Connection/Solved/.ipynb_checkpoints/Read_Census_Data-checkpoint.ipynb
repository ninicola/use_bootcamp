# %%
# !pip install pymysql
# Out:
# Collecting pymysql
#   Downloading https://files.pythonhosted.org/packages/a7/7d/682c4a7da195a678047c8f1c51bb7682aaedee1dca7547883c3993ca9282/PyMySQL-0.9.2-py2.py3-none-any.whl (47kB)
#     100% |████████████████████████████████| 51kB 311kB/s ta 0:00:01
# Requirement already satisfied: cryptography in /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages (from pymysql) (2.1.4)
# Requirement already satisfied: idna>=2.1 in /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages (from cryptography->pymysql) (2.6)
# Requirement already satisfied: asn1crypto>=0.21.0 in /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages (from cryptography->pymysql) (0.24.0)
# Requirement already satisfied: six>=1.4.1 in /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages (from cryptography->pymysql) (1.11.0)
# Requirement already satisfied: cffi>=1.7 in /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages (from cryptography->pymysql) (1.11.4)
# Requirement already satisfied: pycparser in /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages (from cffi>=1.7->cryptography->pymysql) (2.18)
# Installing collected packages: pymysql
# Successfully installed pymysql-0.9.2
# You are using pip version 10.0.1, however version 18.0 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# SQL Alchemy
from sqlalchemy import create_engine

# PyMySQL 
import pymysql
pymysql.install_as_MySQLdb()

# %%
# Create Engine and Pass in MySQL Connection
engine = create_engine("mysql://k5xunpkmojyzse51:ifagg1gp7e2xyapi@ffn96u87j5ogvehy.cbetxkdyhwsb.us-east-1.rds.amazonaws.com:3306/tq6h098h0ym00zp6")

# %%
# Query All Records in the the Database
data = engine.execute("SELECT * FROM Census_Data")

for record in data:
    print(record)
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages/pymysql/connections.py in _read_bytes(self, num_bytes)
#     689             try:
# --> 690                 data = self._rfile.read(num_bytes)
#     691                 break
#
# /anaconda3/envs/PythonSuperMan/lib/python3.6/socket.py in readinto(self, b)
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#
# ConnectionResetError: [Errno 54] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#
# /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages/sqlalchemy/pool.py in connect(self)
#     402         if not self._use_threadlocal:
# --> 403             return _ConnectionFairy._checkout(self)
#     404
#
# /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages/sqlalchemy/pool.py in _checkout(cls, pool, threadconns, fairy)
#     781         if not fairy:
# --> 782             fairy = _ConnectionRecord.checkout(pool)
#     783
#
# /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages/sqlalchemy/pool.py in checkout(cls, pool)
#     531     def checkout(cls, pool):
# --> 532         rec = pool._do_get()
#     533         try:
#
# /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1185                 with util.safe_reraise():
# -> 1186                     self._dec_overflow()
#    1187         else:
#
# /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      65             if not self.warn_only:
# ---> 66                 compat.reraise(exc_type, exc_value, exc_tb)
#      67         else:
#
# /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     186             raise value.with_traceback(tb)
# --> 187         raise value
#     188
#
# /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1182             try:
# -> 1183                 return self._create_connection()
#    1184             except:
#
# /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages/sqlalchemy/pool.py in _create_connection(self)
#     349
# --> 350         return _ConnectionRecord(self)
#     351
#
# /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages/sqlalchemy/pool.py in __init__(self, pool, connect)
#     476         if connect:
# --> 477             self.__connect(first_connect_check=True)
#     478         self.finalize_callback = deque()
#
# /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages/sqlalchemy/pool.py in __connect(self, first_connect_check)
#     666             self.starttime = time.time()
# --> 667             connection = pool._invoke_creator(self)
#     668             pool.logger.debug("Created new connection %r", connection)
#
# /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     104                             return connection
# --> 105                 return dialect.connect(*cargs, **cparams)
#     106
#
# /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     409     def connect(self, *cargs, **cparams):
# --> 410         return self.dbapi.connect(*cargs, **cparams)
#     411
#
# /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages/pymysql/__init__.py in Connect(*args, **kwargs)
#      93     from .connections import Connection
# ---> 94     return Connection(*args, **kwargs)
#      95
#
# /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages/pymysql/connections.py in __init__(self, host, user, password, database, port, unix_socket, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, ssl, read_default_group, compress, named_pipe, autocommit, db, passwd, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key)
#     326         else:
# --> 327             self.connect()
#     328
#
# /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages/pymysql/connections.py in connect(self, sock)
#     596
# --> 597             self._get_server_information()
#     598             self._request_authentication()
#
# /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages/pymysql/connections.py in _get_server_information(self)
#     965         i = 0
# --> 966         packet = self._read_packet()
#     967         data = packet.get_all_data()
#
# /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     655         while True:
# --> 656             packet_header = self._read_bytes(4)
#     657             #if DEBUG: dump_packet(packet_header)
#
# /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages/pymysql/connections.py in _read_bytes(self, num_bytes)
#     697                     CR.CR_SERVER_LOST,
# --> 698                     "Lost connection to MySQL server during query (%s)" % (e,))
#     699         if len(data) < num_bytes:
#
# OperationalError: (2013, 'Lost connection to MySQL server during query ([Errno 54] Connection reset by peer)')
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-8-2e49778698f4> in <module>()
#       1 # Query All Records in the the Database
# ----> 2 data = engine.execute("SELECT * FROM Census_Data")
#       3
#       4 for record in data:
#       5     print(record)
#
# /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    2072         """
#    2073
# -> 2074         connection = self.contextual_connect(close_with_result=True)
#    2075         return connection.execute(statement, *multiparams, **params)
#    2076
#
# /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages/sqlalchemy/engine/base.py in contextual_connect(self, close_with_result, **kwargs)
#    2121         return self._connection_cls(
#    2122             self,
# -> 2123             self._wrap_pool_connect(self.pool.connect, None),
#    2124             close_with_result=close_with_result,
#    2125             **kwargs)
#
# /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2160             if connection is None:
#    2161                 Connection._handle_dbapi_exception_noconnection(
# -> 2162                     e, dialect, self)
#    2163             else:
#    2164                 util.reraise(*sys.exc_info())
#
# /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1474             util.raise_from_cause(
#    1475                 sqlalchemy_exception,
# -> 1476                 exc_info
#    1477             )
#    1478         else:
#
# /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     201     exc_type, exc_value, exc_tb = exc_info
#     202     cause = exc_value if exc_value is not exception else None
# --> 203     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     204
#     205 if py3k:
#
# /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     184             value.__cause__ = cause
#     185         if value.__traceback__ is not tb:
# --> 186             raise value.with_traceback(tb)
#     187         raise value
#     188
#
# /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2156         dialect = self.dialect
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#    2160             if connection is None:
#
# /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages/sqlalchemy/pool.py in connect(self)
#     401         """
#     402         if not self._use_threadlocal:
# --> 403             return _ConnectionFairy._checkout(self)
#     404
#     405         try:
#
# /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages/sqlalchemy/pool.py in _checkout(cls, pool, threadconns, fairy)
#     780     def _checkout(cls, pool, threadconns=None, fairy=None):
#     781         if not fairy:
# --> 782             fairy = _ConnectionRecord.checkout(pool)
#     783
#     784             fairy._pool = pool
#
# /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages/sqlalchemy/pool.py in checkout(cls, pool)
#     530     @classmethod
#     531     def checkout(cls, pool):
# --> 532         rec = pool._do_get()
#     533         try:
#     534             dbapi_connection = rec.get_connection()
#
# /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1184             except:
#    1185                 with util.safe_reraise():
# -> 1186                     self._dec_overflow()
#    1187         else:
#    1188             return self._do_get()
#
# /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      64             self._exc_info = None   # remove potential circular references
#      65             if not self.warn_only:
# ---> 66                 compat.reraise(exc_type, exc_value, exc_tb)
#      67         else:
#      68             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     185         if value.__traceback__ is not tb:
#     186             raise value.with_traceback(tb)
# --> 187         raise value
#     188
#     189 else:
#
# /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1181         if self._inc_overflow():
#    1182             try:
# -> 1183                 return self._create_connection()
#    1184             except:
#    1185                 with util.safe_reraise():
#
# /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages/sqlalchemy/pool.py in _create_connection(self)
#     348         """Called by subclasses to create a new ConnectionRecord."""
#     349
# --> 350         return _ConnectionRecord(self)
#     351
#     352     def _invalidate(self, connection, exception=None, _checkin=True):
#
# /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages/sqlalchemy/pool.py in __init__(self, pool, connect)
#     475         self.__pool = pool
#     476         if connect:
# --> 477             self.__connect(first_connect_check=True)
#     478         self.finalize_callback = deque()
#     479
#
# /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages/sqlalchemy/pool.py in __connect(self, first_connect_check)
#     665         try:
#     666             self.starttime = time.time()
# --> 667             connection = pool._invoke_creator(self)
#     668             pool.logger.debug("Created new connection %r", connection)
#     669             self.connection = connection
#
# /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     103                         if connection is not None:
#     104                             return connection
# --> 105                 return dialect.connect(*cargs, **cparams)
#     106
#     107             creator = pop_kwarg('creator', connect)
#
# /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     408
#     409     def connect(self, *cargs, **cparams):
# --> 410         return self.dbapi.connect(*cargs, **cparams)
#     411
#     412     def create_connect_args(self, url):
#
# /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages/pymysql/__init__.py in Connect(*args, **kwargs)
#      92     """
#      93     from .connections import Connection
# ---> 94     return Connection(*args, **kwargs)
#      95
#      96 from . import connections as _orig_conn
#
# /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages/pymysql/connections.py in __init__(self, host, user, password, database, port, unix_socket, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, ssl, read_default_group, compress, named_pipe, autocommit, db, passwd, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key)
#     325             self._sock = None
#     326         else:
# --> 327             self.connect()
#     328
#     329     def _create_ssl_ctx(self, sslp):
#
# /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages/pymysql/connections.py in connect(self, sock)
#     595             self._next_seq_id = 0
#     596
# --> 597             self._get_server_information()
#     598             self._request_authentication()
#     599
#
# /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages/pymysql/connections.py in _get_server_information(self)
#     964     def _get_server_information(self):
#     965         i = 0
# --> 966         packet = self._read_packet()
#     967         data = packet.get_all_data()
#     968
#
# /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     654         buff = b''
#     655         while True:
# --> 656             packet_header = self._read_bytes(4)
#     657             #if DEBUG: dump_packet(packet_header)
#     658
#
# /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages/pymysql/connections.py in _read_bytes(self, num_bytes)
#     696                 raise err.OperationalError(
#     697                     CR.CR_SERVER_LOST,
# --> 698                     "Lost connection to MySQL server during query (%s)" % (e,))
#     699         if len(data) < num_bytes:
#     700             self._force_close()
#
# OperationalError: (pymysql.err.OperationalError) (2013, 'Lost connection to MySQL server during query ([Errno 54] Connection reset by peer)') (Background on this error at: http://sqlalche.me/e/e3q8)

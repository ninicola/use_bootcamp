# %%
# !pip install https://github.com/slimkrazy/python-google-places/zipball/master
# Out:
# Collecting https://github.com/slimkrazy/python-google-places/zipball/master
#   Downloading https://github.com/slimkrazy/python-google-places/zipball/master
# Requirement already satisfied (use --upgrade to upgrade): python-google-places==1.4.1 from https://github.com/slimkrazy/python-google-places/zipball/master in /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages
# Requirement already satisfied: six in /anaconda3/envs/PythonSuperMan/lib/python3.6/site-packages (from python-google-places==1.4.1) (1.11.0)
# Building wheels for collected packages: python-google-places
#   Running setup.py bdist_wheel for python-google-places ... done
#   Stored in directory: /private/var/folders/8m/fg7gnxfd21gccxrwb54jfw0h0000gn/T/pip-ephem-wheel-cache-u72e_gtd/wheels/b4/7a/c0/3d97229a8680a7f817e121b52d65530c0eaf17bc0c4fe8bdb9
# Successfully built python-google-places

# %%
from googleplaces import GooglePlaces, types, lang

YOUR_API_KEY = 'AIzaSyBy41KtJA4P60Qkc5H0ayLd8yQETGqM6UI'

google_places = GooglePlaces(YOUR_API_KEY)

# You may prefer to use the text_search API, instead.
query_result = google_places.nearby_search(
        location='London, England', keyword='Fish and Chips',
        radius=20000, types=[types.TYPE_FOOD])
# If types param contains only 1 item the request to Google Places API
# will be send as type param to fullfil:
# http://googlegeodevelopers.blogspot.com.au/2016/02/changes-and-quality-improvements-in_16.html

if query_result.has_attributions:
    print(query_result.html_attributions)


for place in query_result.places:
    # Returned places from a query are place summaries.
    print(place.name)
    print(place.geo_location)
    print(place.place_id)

    # The following method has to make a further API call.
    place.get_details()
    # Referencing any of the attributes below, prior to making a call to
    # get_details() will raise a googleplaces.GooglePlacesAttributeError.
    print(place.details) # A dict matching the JSON response from Google.
    print(place.local_phone_number)
    print(place.international_phone_number)
    print(place.website)
    print (place.url)

    # Getting place photos

    for photo in place.photos:
        # 'maxheight' or 'maxwidth' is required
        photo.get(maxheight=500, maxwidth=500)
        # MIME-type, e.g. 'image/jpeg'
        photo.mimetype
        # Image URL
        photo.url
        # Original filename (optional)
        photo.filename
        # Raw image data
        photo.data


# Are there any additional pages of results?
if query_result.has_next_page_token:
    query_result_next_page = google_places.nearby_search(
            pagetoken=query_result.next_page_token)


# Adding and deleting a place
try:
    added_place = google_places.add_place(name='Mom and Pop local store',
            lat_lng={'lat': 51.501984, 'lng': -0.141792},
            accuracy=100,
            types=types.TYPE_HOME_GOODS_STORE,
            language=lang.ENGLISH_GREAT_BRITAIN)
    print(added_place.place_id) # The Google Places identifier - Important!
    print(added_place.id)

    # Delete the place that you've just added.
    google_places.delete_place(added_place.place_id)
except GooglePlacesError as error_detail:
    # You've passed in parameter values that the Places API doesn't like..
    print(error_detail)
# Out:
# Poppies Fish & Chips, Spitalfields
# {'lat': Decimal('51.5202235'), 'lng': Decimal('-0.0740232')}
# ChIJX7eIgrYcdkgRJtmJIysIZVc
# {'address_components': [{'long_name': '6-8', 'short_name': '6-8', 'types': ['street_number']}, {'long_name': 'Hanbury Street', 'short_name': 'Hanbury St', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'E1 6QR', 'short_name': 'E1 6QR', 'types': ['postal_code']}], 'adr_address': '<span class="street-address">6-8 Hanbury St</span>, <span class="locality">London</span> <span class="postal-code">E1 6QR</span>, <span class="country-name">UK</span>', 'formatted_address': '6-8 Hanbury St, London E1 6QR, UK', 'formatted_phone_number': '020 7247 0892', 'geometry': {'location': {'lat': Decimal('51.52022349999999'), 'lng': Decimal('-0.0740232')}, 'viewport': {'northeast': {'lat': Decimal('51.5216096802915'), 'lng': Decimal('-0.07268096970849797')}, 'southwest': {'lat': Decimal('51.5189117197085'), 'lng': Decimal('-0.07537893029150203')}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png', 'id': 'acfa9a465c3081aec87cf46e06d1d04cdcaa7c77', 'international_phone_number': '+44 20 7247 0892', 'name': 'Poppies Fish & Chips, Spitalfields', 'opening_hours': {'open_now': True, 'periods': [{'close': {'day': 0, 'time': '2230'}, 'open': {'day': 0, 'time': '1100'}}, {'close': {'day': 1, 'time': '2300'}, 'open': {'day': 1, 'time': '1100'}}, {'close': {'day': 2, 'time': '2300'}, 'open': {'day': 2, 'time': '1100'}}, {'close': {'day': 3, 'time': '2300'}, 'open': {'day': 3, 'time': '1100'}}, {'close': {'day': 4, 'time': '2300'}, 'open': {'day': 4, 'time': '1100'}}, {'close': {'day': 5, 'time': '2330'}, 'open': {'day': 5, 'time': '1100'}}, {'close': {'day': 6, 'time': '2330'}, 'open': {'day': 6, 'time': '1100'}}], 'weekday_text': ['Monday: 11:00 AM – 11:00 PM', 'Tuesday: 11:00 AM – 11:00 PM', 'Wednesday: 11:00 AM – 11:00 PM', 'Thursday: 11:00 AM – 11:00 PM', 'Friday: 11:00 AM – 11:30 PM', 'Saturday: 11:00 AM – 11:30 PM', 'Sunday: 11:00 AM – 10:30 PM']}, 'photos': [{'height': 800, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113720139114503177031/photos">Poppies Fish &amp; Chips, Spitalfields</a>'], 'photo_reference': 'CmRaAAAA_0l2enyBuWG171HxqCghYkuk2S9xDAxKmLQfIAzzV_ZjyeMxqsOkJYPlCHExYjrp5YRHW_W6uXOvW2gx6zvQ1PKYy-MPHWxh2JXDviYDcnxiDfEgvRRkxRyhCFn94eHEEhDMQCX-MwfiERchwMz82JXfGhQPFRTzelYK8ZybQBJD5Guwzj5BjQ', 'width': 1200}, {'height': 3024, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102060093835083317548/photos">Bob Zhang</a>'], 'photo_reference': 'CmRaAAAASMOyuXmI2TFfH1p678xhscQ9umF17fBbZuYhqOoOh6NxlyB3eykoS_mChStqAhrcnfd4gYhdhY74ac14iqDcAeRCV18JHBCSQGLim5oePzIImnq7XFmKCbd6grSOBE48EhCV0o4yXw5jgckGHUlIO0lnGhQwgYz0Y9JH1AGlkCcGrd361eWCww', 'width': 4032}, {'height': 1360, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113720139114503177031/photos">Poppies Fish &amp; Chips, Spitalfields</a>'], 'photo_reference': 'CmRaAAAA8KnoubCfoh-q7uVq0L27j5daH1fDMDQqNQuey7KuqNGHbEGhELm3rntPGE2YdsTyKClkO7rce2L4ADFe1aKgKNhXKnaJvkwGTmC3iMy0Ksko3XLZlYnmCuWvIGRRQB55EhBcUlmEN_s5wZZ67MKPVobfGhSxJ4qkfGzvNoFSLDfAxBHkcZwziQ', 'width': 2048}, {'height': 1343, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118008305675879084685/photos">Happening London</a>'], 'photo_reference': 'CmRaAAAATMCLoSW5Qf6z-F7CUT2Q7cYdcWuI-gt69kbh4b8YGfKViR8i2n5j48tVTbYELMJn8HdZxG65lsRLS5yUg_yZyHzWOaSZFHXt_Dn75pO5ineVDNcRkf9QX8GVxkAz0dhwEhAXNdlViklu5QIvybuo97CBGhQMgH50QFiJowt3ilQns13gzaVnDw', 'width': 2031}, {'height': 2322, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100191395553422391685/photos">Haluk Unal</a>'], 'photo_reference': 'CmRaAAAAQ8GghTmDmUQDwSqFyuz9uobookegb0NmfjTyVYoB3zIg2NQRV8DtyP ...
# 020 7247 0892
# +44 20 7247 0892
# http://www.poppiesfishandchips.co.uk/
# https://maps.google.com/?cid=6297448635320359206
# Poppies Fish and Chips Camden
# {'lat': Decimal('51.5409757'), 'lng': Decimal('-0.1439713')}
# ChIJGZ-kgeEadkgRrmwbc4LrXGI
# {'address_components': [{'long_name': '30', 'short_name': '30', 'types': ['street_number']}, {'long_name': 'Hawley Crescent', 'short_name': 'Hawley Cres', 'types': ['route']}, {'long_name': 'Camden Town', 'short_name': 'Camden Town', 'types': ['neighborhood', 'political']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'NW1 8NP', 'short_name': 'NW1 8NP', 'types': ['postal_code']}], 'adr_address': '<span class="street-address">30 Hawley Cres</span>, <span class="locality">London</span> <span class="postal-code">NW1 8NP</span>, <span class="country-name">UK</span>', 'formatted_address': '30 Hawley Cres, Camden Town, London NW1 8NP, UK', 'formatted_phone_number': '020 7267 0440', 'geometry': {'location': {'lat': Decimal('51.5409757'), 'lng': Decimal('-0.1439713')}, 'viewport': {'northeast': {'lat': Decimal('51.5422597802915'), 'lng': Decimal('-0.142583869708498')}, 'southwest': {'lat': Decimal('51.5395618197085'), 'lng': Decimal('-0.145281830291502')}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png', 'id': 'e0715c3d882f1db32231494d012b7459d7fd8ab9', 'international_phone_number': '+44 20 7267 0440', 'name': 'Poppies Fish and Chips Camden', 'opening_hours': {'open_now': True, 'periods': [{'close': {'day': 0, 'time': '2230'}, 'open': {'day': 0, 'time': '1100'}}, {'close': {'day': 1, 'time': '2300'}, 'open': {'day': 1, 'time': '1100'}}, {'close': {'day': 2, 'time': '2300'}, 'open': {'day': 2, 'time': '1100'}}, {'close': {'day': 3, 'time': '2300'}, 'open': {'day': 3, 'time': '1100'}}, {'close': {'day': 4, 'time': '2300'}, 'open': {'day': 4, 'time': '1100'}}, {'close': {'day': 5, 'time': '2330'}, 'open': {'day': 5, 'time': '1100'}}, {'close': {'day': 6, 'time': '2330'}, 'open': {'day': 6, 'time': '1100'}}], 'weekday_text': ['Monday: 11:00 AM – 11:00 PM', 'Tuesday: 11:00 AM – 11:00 PM', 'Wednesday: 11:00 AM – 11:00 PM', 'Thursday: 11:00 AM – 11:00 PM', 'Friday: 11:00 AM – 11:30 PM', 'Saturday: 11:00 AM – 11:30 PM', 'Sunday: 11:00 AM – 10:30 PM']}, 'photos': [{'height': 2988, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101703475998391445096/photos">Ivana Mercuriali</a>'], 'photo_reference': 'CmRaAAAAaY0MvMI4-RGEMLzjQGmew_kO2MN8z1t3DWO4REGiggLbUh5gMV2dThTBs1H96tT8fBVMAz4m2fRXQkrpVvpAWuIl8O-f0RfdVXfmtn6PNEcCBQ239tizcSDu9n851EleEhCnFRZy6uhtD67DULS93WikGhSniMhVVmkEGNzM7qvpbUM-bEqeKQ', 'width': 5312}, {'height': 3024, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107335556111498895394/photos">Cassandra Li</a>'], 'photo_reference': 'CmRaAAAAzMZW3v1l3cu1Bfnzg5m-lUNarok7zlxSIkokGiGNmQxQKoQhAGrStXWHoIOLX53tUoDYKQWHBkhAM_Qp-Q5lfoNTiOPyOz4E8Xogs28P2V3GfQIXXLZMckcrjBvPecV6EhDEWX3TVsUddfeHgFc5B_rrGhTNl6gWUHDEDr4Ce1e0o04o2VkxNA', 'width': 4032}, {'height': 2248, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105099663444078965857/photos">Coşkun Bal</a>'], 'photo_reference': 'CmRaAAAA7MnDShsHtYs4ttdlMKv6z7Oo0WHdPdoF1jk6K-ZlayHhRlH2b-7SrURsw-F6pNzTvPjDcL1AwspPcAG0HCRgpsvTQoFuBEEUi3QpmtsrLXpcCMwZddvAtm0ISQUI0LMnEhBQmzFRWFDxPqSGQ0fous-fGhQnaAqmBUrVt_6Qg2tIY69-LTvjSA', 'width': 4000}, {'height': 2336, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108590082474159217684/photos">Fofuken</a>'], 'photo_reference': 'CmRaAAAAYZV-95VnXgP_C3Kxgc7vJxzGTYv3tgQKYb-MytMF4ksbyK6brqbNjVXmBWDlnHi22ia0hNx_hdJihd2a88Zna7p_n1vFSsW5dW4E9qYBDaU4uLSL6wxn9Efx_y-U5wR4EhA6F2dQyzgBjbEBxgzmPDAmGhT6Rw-_Y4kl5JjiiosD_RXYSI-AFg', 'width': 4160}, {'height': 3168, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106247618138032632337/photos">Poppies Fish and Chips - Camden</a>'], 'photo_reference ...
# 020 7267 0440
# +44 20 7267 0440
# http://www.poppiesfishandchips.co.uk/
# https://maps.google.com/?cid=7087798859083771054
# Hobson's Fish & Chips
# {'lat': Decimal('51.516583'), 'lng': Decimal('-0.187945')}
# ChIJi1a_naoadkgRpmgQ8gWTT54
# {'address_components': [{'long_name': '9', 'short_name': '9', 'types': ['street_number']}, {'long_name': 'Porchester Road', 'short_name': 'Porchester Rd', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'W2 5DP', 'short_name': 'W2 5DP', 'types': ['postal_code']}], 'adr_address': '<span class="street-address">9 Porchester Rd</span>, <span class="locality">London</span> <span class="postal-code">W2 5DP</span>, <span class="country-name">UK</span>', 'formatted_address': '9 Porchester Rd, London W2 5DP, UK', 'formatted_phone_number': '020 7229 4161', 'geometry': {'location': {'lat': Decimal('51.516583'), 'lng': Decimal('-0.187945')}, 'viewport': {'northeast': {'lat': Decimal('51.5179572302915'), 'lng': Decimal('-0.186504769708498')}, 'southwest': {'lat': Decimal('51.5152592697085'), 'lng': Decimal('-0.189202730291502')}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png', 'id': 'a3ffdcb1013a65fb4b4f2937eaf73b842afa1e32', 'international_phone_number': '+44 20 7229 4161', 'name': "Hobson's Fish & Chips", 'opening_hours': {'open_now': True, 'periods': [{'close': {'day': 0, 'time': '2300'}, 'open': {'day': 0, 'time': '1200'}}, {'close': {'day': 1, 'time': '2300'}, 'open': {'day': 1, 'time': '1200'}}, {'close': {'day': 2, 'time': '2300'}, 'open': {'day': 2, 'time': '1200'}}, {'close': {'day': 3, 'time': '2300'}, 'open': {'day': 3, 'time': '1200'}}, {'close': {'day': 4, 'time': '2300'}, 'open': {'day': 4, 'time': '1200'}}, {'close': {'day': 5, 'time': '2300'}, 'open': {'day': 5, 'time': '1200'}}, {'close': {'day': 6, 'time': '2300'}, 'open': {'day': 6, 'time': '1200'}}], 'weekday_text': ['Monday: 12:00 – 11:00 PM', 'Tuesday: 12:00 – 11:00 PM', 'Wednesday: 12:00 – 11:00 PM', 'Thursday: 12:00 – 11:00 PM', 'Friday: 12:00 – 11:00 PM', 'Saturday: 12:00 – 11:00 PM', 'Sunday: 12:00 – 11:00 PM']}, 'photos': [{'height': 3307, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108347313474104880678/photos">Hobson&#39;s Fish &amp; Chips</a>'], 'photo_reference': 'CmRaAAAA491ySkyqVajIItphx9l0sTEoobyWsrmysedIrRlY-RMUzPJa8BfMnZnwkA6fwxxmOLgrDLvdKm1K9Ba6WqlXy-LfQ9u--uGEp4N4Og56gtjrxGEj2oLzbAWzrpltl7khEhAIUYYHQpCb6687enqSt5fgGhRjmlruI1ckH5HGd7D7lJFDv8BzbA', 'width': 5022}, {'height': 3024, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110131934322527935323/photos">Lorenzo Gallucci</a>'], 'photo_reference': 'CmRaAAAA2MynkLbEK7ZXfr39BmQlNrE0TNZuoLCFqKKRH8chyrDmbVbeSX-CfM8oZUR4xweRiggYupH2LAQyg9F6nvKjoPyHgd-pnvFnACpFcaF4GAEFoIDZ83pgNPtq7KxIw9soEhDQEGSwTIcYtprmLezC6VfkGhT7_eUfG-7FXsfNAQuruUVVwMEqLQ', 'width': 4032}, {'height': 1536, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113385753149112562337/photos">See Ming Jie</a>'], 'photo_reference': 'CmRaAAAAUuSS3YRNrFUTZiiead-5hQHlPcDRELRqB1pVZxOBRIlJ8cDKWHewNMM7bwDdttcZ_GWJhzXZBJS1ccfvBBSiZIOt2m4SpBUJum-3RrfRDOIv3b8Xbs---hge4kPtPoFMEhCOV4CH5mM87t9LkTKZqkf8GhT4nLYKzAoEsxIs8zuxGrd2viv9cA', 'width': 2048}, {'height': 1280, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107397903097940767182/photos">Max Dubs</a>'], 'photo_reference': 'CmRaAAAAjS4sRPD2zYcC_IN_XmLFtHcaDQed9yJhAGFq7VEakcGKxNr_RC5ZQ5y7dqbaBKR33QGf8ilikEvAN7t2MDlAvQCN7vcxxIcLlSNkbGTVsuuYo-f66d0idhLPZLfPqWPKEhCE1aSDqAfpcXNFuzh8uwHkGhQ31Gh9MeqKEsUlhbs2gwx9XZ4MAA', 'width': 960}, {'height': 3456, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108347313474104880678/photos">Hobson&#39;s Fish &amp; Chips</a>'], 'photo_reference': 'CmRaAAAAWBmdc67CRlBqrTsBZKlUKqHBJ6B3JqquUXQhfknirSyiqrtsvkFxG5Sa9cjrvATOi_ypiRV6qzZ3K6JihECxMKnzs01iMOHF3-eBGDVwX83dZES_Yk_G ...
# 020 7229 4161
# +44 20 7229 4161
# http://www.hobsonsfishandchips.com/
# https://maps.google.com/?cid=11407498034898036902
# Fishers
# {'lat': Decimal('51.470954'), 'lng': Decimal('-0.210788')}
# ChIJbfhNMHUPdkgRuFpD4GATdQQ
# {'address_components': [{'long_name': '19', 'short_name': '19', 'types': ['street_number']}, {'long_name': 'Fulham High Street', 'short_name': 'Fulham High St', 'types': ['route']}, {'long_name': 'Fulham', 'short_name': 'Fulham', 'types': ['neighborhood', 'political']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'SW6 3JH', 'short_name': 'SW6 3JH', 'types': ['postal_code']}], 'adr_address': '<span class="street-address">19 Fulham High St</span>, <span class="locality">London</span> <span class="postal-code">SW6 3JH</span>, <span class="country-name">UK</span>', 'formatted_address': '19 Fulham High St, Fulham, London SW6 3JH, UK', 'formatted_phone_number': '020 7371 5555', 'geometry': {'location': {'lat': Decimal('51.470954'), 'lng': Decimal('-0.210788')}, 'viewport': {'northeast': {'lat': Decimal('51.47228463029149'), 'lng': Decimal('-0.209514719708498')}, 'southwest': {'lat': Decimal('51.46958666970849'), 'lng': Decimal('-0.212212680291502')}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png', 'id': '516c26014819a47f89857f0f7ba3f2700f4a6cea', 'international_phone_number': '+44 20 7371 5555', 'name': 'Fishers', 'opening_hours': {'open_now': True, 'periods': [{'close': {'day': 0, 'time': '2230'}, 'open': {'day': 0, 'time': '1200'}}, {'close': {'day': 1, 'time': '2230'}, 'open': {'day': 1, 'time': '1200'}}, {'close': {'day': 2, 'time': '2230'}, 'open': {'day': 2, 'time': '1200'}}, {'close': {'day': 3, 'time': '2230'}, 'open': {'day': 3, 'time': '1200'}}, {'close': {'day': 4, 'time': '2230'}, 'open': {'day': 4, 'time': '1200'}}, {'close': {'day': 5, 'time': '2230'}, 'open': {'day': 5, 'time': '1200'}}, {'close': {'day': 6, 'time': '2230'}, 'open': {'day': 6, 'time': '1200'}}], 'weekday_text': ['Monday: 12:00 – 10:30 PM', 'Tuesday: 12:00 – 10:30 PM', 'Wednesday: 12:00 – 10:30 PM', 'Thursday: 12:00 – 10:30 PM', 'Friday: 12:00 – 10:30 PM', 'Saturday: 12:00 – 10:30 PM', 'Sunday: 12:00 – 10:30 PM']}, 'photos': [{'height': 3024, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101456829970215111932/photos">sonia cavecchi</a>'], 'photo_reference': 'CmRaAAAApnC23dSgTL-ZBZrOgwaL_jt1tc4OJt9wVuAhbk446a3Setq7cGCuitOhzVF38KP7OyLIylPAfDAG15z2C8VDiB0b1F9oEYNxCXHAz4X2CNX8iUrGYtHJhOkasLBZJ8jlEhC2cKX4d5NPvInIUbVuOuYnGhR0OYNhyVArKCqUB34sQHXLN25BCQ', 'width': 4032}, {'height': 2448, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115237116068746339777/photos">Adam Czarnecki</a>'], 'photo_reference': 'CmRaAAAApmyDcEAldNHBhigNUuYemB3GUseewIc439YrTCZhE5gXLp4u876w6FMLgTd8_ca4yJjxO1R75j8bDhamd-q8dPMFDpYHg7xSYVCYACRFTE3aI1hZJt_pcSRknLtpgf4HEhBX91eDTDO22l9aOqOEx7i7GhQGhl72zIyaq_s0oSdp5cl3kUnZnA', 'width': 3264}, {'height': 5312, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101986313586048004438/photos">V Lyster</a>'], 'photo_reference': 'CmRaAAAANy-vw1a3wWkgj3avESzmthwDI3LOmeFhCFj1szz8DcXoBJPa_m0np64nchp9TtfbD7zinpb8Aew1f9EnzocN0KXR0_Bh8WsLeq-5wuM_OYxKWW4F3sS4swhEIr5eoTaeEhAQCgnKHJAKCwBp9gtR4pXAGhRDXEfRMBA68P5egVezPjLEjFzwwQ', 'width': 2988}, {'height': 3120, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110538464657887695131/photos">Benoit Angebault</a>'], 'photo_reference': 'CmRaAAAAM59rt0g8MQsFbx6YrDE8IHoXZn8x2fZblHbUFYO7NoYINYURRUwR6y04ASrLFSNEpV82_nrAc196LYtXgBPmtYeuJ4DwnfmYJmb4CWioXb-sdDg_p8U4xoNb5pbFh7mxEhCRcnDnTrhCzF4vYr2uocZ8GhSinK81MgXFd5VBagwQi8KseNdcgw', 'width': 4160}, {'height': 2992, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100256520766255656424/photos">Aishwarya Singh</a>'], 'photo_reference': 'CmRaAAAAMnoyvERQpc4s8SSFdKwykfdxljP98kLgVIjovwV91f_ ...
# 020 7371 5555
# +44 20 7371 5555
# http://www.fishersfishandchips.co.uk/
# https://maps.google.com/?cid=321184255227157176
# Oliver's Fish & Chips
# {'lat': Decimal('51.546799'), 'lng': Decimal('-0.158716')}
# ChIJn8hI__EadkgRUaIJ8jj2CuY
# {'address_components': [{'long_name': '95', 'short_name': '95', 'types': ['street_number']}, {'long_name': 'Haverstock Hill', 'short_name': 'Haverstock Hill', 'types': ['route']}, {'long_name': 'Belsize Park', 'short_name': 'Belsize Park', 'types': ['neighborhood', 'political']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'NW3 4RL', 'short_name': 'NW3 4RL', 'types': ['postal_code']}], 'adr_address': '<span class="street-address">95 Haverstock Hill</span>, <span class="locality">London</span> <span class="postal-code">NW3 4RL</span>, <span class="country-name">UK</span>', 'formatted_address': '95 Haverstock Hill, Belsize Park, London NW3 4RL, UK', 'formatted_phone_number': '020 7586 9945', 'geometry': {'location': {'lat': Decimal('51.54679900000001'), 'lng': Decimal('-0.158716')}, 'viewport': {'northeast': {'lat': Decimal('51.5481906802915'), 'lng': Decimal('-0.157317819708498')}, 'southwest': {'lat': Decimal('51.54549271970851'), 'lng': Decimal('-0.160015780291502')}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png', 'id': 'bab53620edb6cf4daf2122ee7f47827d963ba0a5', 'international_phone_number': '+44 20 7586 9945', 'name': "Oliver's Fish & Chips", 'opening_hours': {'open_now': True, 'periods': [{'close': {'day': 0, 'time': '2215'}, 'open': {'day': 0, 'time': '1215'}}, {'close': {'day': 2, 'time': '2215'}, 'open': {'day': 2, 'time': '1215'}}, {'close': {'day': 3, 'time': '2215'}, 'open': {'day': 3, 'time': '1215'}}, {'close': {'day': 4, 'time': '2215'}, 'open': {'day': 4, 'time': '1215'}}, {'close': {'day': 5, 'time': '2215'}, 'open': {'day': 5, 'time': '1215'}}, {'close': {'day': 6, 'time': '2215'}, 'open': {'day': 6, 'time': '1215'}}], 'weekday_text': ['Monday: Closed', 'Tuesday: 12:15 – 10:15 PM', 'Wednesday: 12:15 – 10:15 PM', 'Thursday: 12:15 – 10:15 PM', 'Friday: 12:15 – 10:15 PM', 'Saturday: 12:15 – 10:15 PM', 'Sunday: 12:15 – 10:15 PM']}, 'photos': [{'height': 1026, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117775761624809833603/photos">Oliver&#39;s Fish &amp; Chips</a>'], 'photo_reference': 'CmRZAAAAt5bRoMxc0CmaBExRU1y27hjArRO0LXddKZ8uH_VTTwLCUAufYSssXu9JOpjSFWD11BAqaHk_1UK_fZnhYxWL9jybkB2OJBRmJ416q3zeY_0M20adz1EbHH8ItF0NLZDPEhDNEw_rtTdzZ4FprljWqgKlGhQSuIeihX9KUSwQzgaGYd32SnBeFQ', 'width': 1248}, {'height': 500, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117775761624809833603/photos">Oliver&#39;s Fish &amp; Chips</a>'], 'photo_reference': 'CmRZAAAA7l1d_i7EQdfigPLLHud_n94DE5eKQy4c4NedED2Wu-VnKdEuTb_U0TOqKerXDx5uRQ9TH7POT8wKwjffB_LPP8qIL2GCKfzOrImbA8KE8adAKarXCy_d-DK-Q4gqNS2aEhAm_8RxVM-bm44FFsxuN8e-GhQT-xq3RoouQegvQ14T4vcGxnSETQ', 'width': 340}, {'height': 2160, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102136347963807067451/photos">Raimonds Kalejs</a>'], 'photo_reference': 'CmRaAAAADK4c2n7r05odOnmMO3uXTObGL1AOx74cfWgjGJDl2dfG4Fw5YJIJZT4WpiQXHABlSm44NumM2_xFMfDrLEkssZtKuiyemMLQBX09U0ouTExJyWSbQyLExXNLhXWVncvzEhAfninIsNSFgNfC_Ord4NcEGhTlLAS6mCQt3lAACY5eGLMaZrIWjg', 'width': 3840}, {'height': 1202, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117775761624809833603/photos">Oliver&#39;s Fish &amp; Chips</a>'], 'photo_reference': 'CmRZAAAAO92Ut-1queIxDtX35oWw9R2uyCT7iVAYhcKo3hA_giHlGjO0JAK5k2iiPztKmplJsOo_Kpc6pNTgWkwCHdA00towELqVZO17gSO4atk7CMg-fhYTjKrz-E2hggLAT4IDEhA2E_EEXsJU4kUlimNlXifDGhTumbRl_tNY1Duy5od9uvg4WkHKnA', 'width': 1601}, {'height': 3648, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117775761624809833603/photos">Oliver&#39;s Fish &amp; Chips</a>'], 'photo_reference': 'CmRZAAAAozkMZrVetMVlE8GIDDLjie9md_b ...
# 020 7586 9945
# +44 20 7586 9945
# http://www.oliversfishandchips.com/
# https://maps.google.com/?cid=16576332102929850961
# Ben's Fish and Chips
# {'lat': Decimal('51.5154662'), 'lng': Decimal('-0.1266079')}
# ChIJoa4D0TIbdkgReCX9s-aeLos
# {'address_components': [{'long_name': '200', 'short_name': '200', 'types': ['street_number']}, {'long_name': 'Shaftesbury Avenue', 'short_name': 'Shaftesbury Ave', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'WC2H 8JL', 'short_name': 'WC2H 8JL', 'types': ['postal_code']}], 'adr_address': '<span class="street-address">200 Shaftesbury Ave</span>, <span class="locality">London</span> <span class="postal-code">WC2H 8JL</span>, <span class="country-name">UK</span>', 'formatted_address': '200 Shaftesbury Ave, London WC2H 8JL, UK', 'formatted_phone_number': '020 7240 3348', 'geometry': {'location': {'lat': Decimal('51.51546620000001'), 'lng': Decimal('-0.1266079')}, 'viewport': {'northeast': {'lat': Decimal('51.5168266802915'), 'lng': Decimal('-0.125342919708498')}, 'southwest': {'lat': Decimal('51.5141287197085'), 'lng': Decimal('-0.128040880291502')}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png', 'id': 'd2525112bb835bcababd2bf202bc50fe3f002b17', 'international_phone_number': '+44 20 7240 3348', 'name': "Ben's Fish and Chips", 'opening_hours': {'open_now': True, 'periods': [{'close': {'day': 0, 'time': '2200'}, 'open': {'day': 0, 'time': '1130'}}, {'close': {'day': 1, 'time': '2300'}, 'open': {'day': 1, 'time': '1100'}}, {'close': {'day': 2, 'time': '2300'}, 'open': {'day': 2, 'time': '1100'}}, {'close': {'day': 3, 'time': '2300'}, 'open': {'day': 3, 'time': '1100'}}, {'close': {'day': 4, 'time': '2300'}, 'open': {'day': 4, 'time': '1100'}}, {'close': {'day': 5, 'time': '2300'}, 'open': {'day': 5, 'time': '1100'}}, {'close': {'day': 6, 'time': '2300'}, 'open': {'day': 6, 'time': '1100'}}], 'weekday_text': ['Monday: 11:00 AM – 11:00 PM', 'Tuesday: 11:00 AM – 11:00 PM', 'Wednesday: 11:00 AM – 11:00 PM', 'Thursday: 11:00 AM – 11:00 PM', 'Friday: 11:00 AM – 11:00 PM', 'Saturday: 11:00 AM – 11:00 PM', 'Sunday: 11:30 AM – 10:00 PM']}, 'photos': [{'height': 960, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115974245653876916196/photos">Ben&#39;s Fish and Chips</a>'], 'photo_reference': 'CmRaAAAAAgQfQnCn1H1OwO_EtuEPhycj_vy_OBpdtb3qTBMOI8QSjN60xHuRG_lpoQqtxtMS4zcDxFDjkjtRs4i3acYWIljwuoCC7lHzuEakRU-kjGHHzUmQVqM7A-g54dgWDKoDEhA1aNAgAnYBa7pNr6Mh2WXNGhQYnLh29-QpFSbN5U3aUCKq7RBKYQ', 'width': 1280}, {'height': 3024, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104894434481475147023/photos">Marco Ramirez</a>'], 'photo_reference': 'CmRaAAAAhwMP9Pasu_zBrDsGcFdcK5yWz5ekzi7GMkn7iut_DbVcMFkWbAYTtLlC8efnMLfEZtv4FO2nPF-K327fX96SfOM0fkjpTDm-tBRCGDX_rjBq0ljkazr_pQaJH1nnVC8aEhCySSaL9OmBBgyzUO2sU1AMGhSTBIt3YzUyeKmXypEvaIP7htFQbw', 'width': 4032}, {'height': 2592, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112854220709181131712/photos">Terence Lee</a>'], 'photo_reference': 'CmRaAAAAlI45RPfRcBXuNKQTWVbDqhvP-lA9WSkvqFcbCIwcXeAdZN5BPgl9D1LlgGh4coAUIKANhNcUAjHrwM4dhEmql9YoEEVUkC9yRoB6AwXn8wC3x6G3IAZ0-KV8dgM9pqjBEhAYBosEGm6PBPKI4662ssoOGhSkmVELMFpRMbFuIQGuP4guUYlxDQ', 'width': 4608}, {'height': 2592, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112854220709181131712/photos">Terence Lee</a>'], 'photo_reference': 'CmRaAAAA7nfqgDCkZdA_Drh06b1ysaqeZzHNE2kTsqwl58XtILBi-fxHBtiHBnXEPOMzSndRglVZCzIbW24eZMlnp1dRKQUFnB0aXGHx4BTDx-BIa_Z300BCHpQujacQguWUwVvEEhDk_XDXZGmIx1PRLKDiKu2hGhQuR4jeV19wa0zH2Z-UjtG-RdBSXw', 'width': 4608}, {'height': 3264, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108923857827923175671/photos">May Tay</a>'], 'photo_reference': 'CmRaAAAAh8ZBUiB47O1O4dfVFw5ArwGST3LoGzyarHG5GncYU_tJANIGMlw2nNwthRrbR3IZU_zIosdEv18RwhQ_DG1v3Vufea ...
# 020 7240 3348
# +44 20 7240 3348
# None
# https://maps.google.com/?cid=10029128133900051832
# Rock and Sole Plaice
# {'lat': Decimal('51.514834'), 'lng': Decimal('-0.125309')}
# ChIJ6wsgLTMbdkgRObEIyzQf10g
# {'address_components': [{'long_name': '45-49', 'short_name': '45-49', 'types': ['street_number']}, {'long_name': 'Endell Street', 'short_name': 'Endell St', 'types': ['route']}, {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']}, {'long_name': 'Greater London', 'short_name': 'Greater London', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}, {'long_name': 'WC2H 9AJ', 'short_name': 'WC2H 9AJ', 'types': ['postal_code']}], 'adr_address': '<span class="street-address">45-49 Endell St</span>, <span class="locality">London</span> <span class="postal-code">WC2H 9AJ</span>, <span class="country-name">UK</span>', 'formatted_address': '45-49 Endell St, London WC2H 9AJ, UK', 'formatted_phone_number': '020 7836 3785', 'geometry': {'location': {'lat': Decimal('51.51483399999999'), 'lng': Decimal('-0.125309')}, 'viewport': {'northeast': {'lat': Decimal('51.5161720802915'), 'lng': Decimal('-0.123835269708498')}, 'southwest': {'lat': Decimal('51.5134741197085'), 'lng': Decimal('-0.126533230291502')}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png', 'id': 'da51233b8235420861e4a5cf60a98851f13228a7', 'international_phone_number': '+44 20 7836 3785', 'name': 'Rock and Sole Plaice', 'opening_hours': {'open_now': True, 'periods': [{'close': {'day': 0, 'time': '2230'}, 'open': {'day': 0, 'time': '1200'}}, {'close': {'day': 1, 'time': '2230'}, 'open': {'day': 1, 'time': '1130'}}, {'close': {'day': 2, 'time': '2230'}, 'open': {'day': 2, 'time': '1130'}}, {'close': {'day': 3, 'time': '2230'}, 'open': {'day': 3, 'time': '1130'}}, {'close': {'day': 4, 'time': '2230'}, 'open': {'day': 4, 'time': '1130'}}, {'close': {'day': 5, 'time': '2230'}, 'open': {'day': 5, 'time': '1130'}}, {'close': {'day': 6, 'time': '2230'}, 'open': {'day': 6, 'time': '1130'}}], 'weekday_text': ['Monday: 11:30 AM – 10:30 PM', 'Tuesday: 11:30 AM – 10:30 PM', 'Wednesday: 11:30 AM – 10:30 PM', 'Thursday: 11:30 AM – 10:30 PM', 'Friday: 11:30 AM – 10:30 PM', 'Saturday: 11:30 AM – 10:30 PM', 'Sunday: 12:00 – 10:30 PM']}, 'photos': [{'height': 3024, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105345856816834178315/photos">Nundou</a>'], 'photo_reference': 'CmRaAAAAZ7aGzR7MgNVLdW9HF6SICchKMjZufNO8XGa3-oqQi-a7nlcuMjjBL6n7bcZBEHuZA0mLCp7tHCA_zhEiAVgaJnoKE_GLwAFksVJDbVo1xNFCyx0pnpeWwmPx4WEQfb08EhALYjjtym14SeSY_h4mzusrGhTffjM-cpQBdXy2dW_hZ2swpZJEkQ', 'width': 4032}, {'height': 3456, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111619392077913611718/photos">정현진</a>'], 'photo_reference': 'CmRaAAAAZ5b-iyYNVzrrsZ5_71xXQAlp302d-QnD_Lbed885nfJjx7MdELmbibSqEhzbwVs_DTXmLkBVdNM9I0LCKC0YLcwTqT1qcJlnsVslIT9Edi_CaA_lnisUL6mUHGe48uluEhDFK4qvJmdq4bUAXEXziRgrGhRq2424NCaO5MQeLDEDXemubFTH0g', 'width': 5184}, {'height': 5312, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103413313854766728675/photos">Gaetano Capuano</a>'], 'photo_reference': 'CmRaAAAADtqqRSEujZiG41OfY3nq9uZ-trTZj_OginzDgyr84R6EfkLr60uw-cErVRoOoysaUFwlgNdijtAvebw3IRvyBNWMPK-njDHEXpd-mC3RmBfpbDdEu6fsZhtl6Bx44Az6EhDieZ9s4ifEeeYEkBRdK_6_GhT3D1osdrh3xFQ6FcDtkWJABMqLVw', 'width': 2988}, {'height': 1960, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113766476783241043626/photos">Dirk Bakker</a>'], 'photo_reference': 'CmRaAAAA_jaP_Ual29EuvqxEd-Bmoa0t8iAFG93zn9-_aqRWW4IfQV6IqJlTjieBIUuovDxdRuO_W4S3GOsXskv5U5tG-QbW6t_O8MYAU5B-fyI-YPFQEVsO7ud2lPpI6NvnoweWEhC1FlKYcdsVCxW9BSbhWEKlGhRHpdcKHlnSVJLuRHovmhnrvUkoEA', 'width': 4032}, {'height': 2268, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103580048305374602692/photos">Sabrina Gualco</a>'], 'photo_reference': 'CmRaAAAAPnGdnXF_E1hVY1Vmpsi_mUUHc2tGKev7gympBiDAMf3macYuoQXre7J973AHNFL5JKWeDoS7UGEoU5ssD1ZKGPmxQcQiIF-51wqxApKp8HuFyBvpez0nxNrAinCtw ...
# 020 7836 3785
# +44 20 7836 3785
# https://www.rockandsoleplaice.com/
# https://maps.google.com/?cid=5248698202328707385

# %%
# Dependencies
# Dependencies
import pandas as pd
import numpy as np
import requests
import json

# Google API Key
from config import gkey
gkey
# Out:
# 'AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0'

# %%
types_df = pd.read_csv("../Resources/ethnic_restr.csv")
types_df.head()
# Out:
#   ethnicity
# 0   chinese
# 1     cuban
# 2     czech
# 3    french
# 4    german

# %%
# set up additional columns to hold information

types_df['name'] = ""
types_df['address'] = ""
types_df['price_level'] = ""
types_df['rating'] = ""

types_df.head()
# Out:
#   ethnicity name address price_level rating
# 0   chinese
# 1     cuban
# 2     czech
# 3    french
# 4    german

# %%
# find the closest restaurant of each type to coordinates

base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {
    "location": "39.952583,-75.16522",  # philadelphia coords,
    "rankby": "distance",
    "type": "restaurant",
    "key": gkey,
}
# use iterrows to iterate through pandas dataframe
for index, row in types_df.iterrows():

    # get restaurant type from df
    restr_type = row['ethnicity']

    # add keyword to params dict
    params['keyword'] = restr_type

    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {restr_type}.")
    response = requests.get(base_url, params=params).json()
    results = response.get('results')
    #print(results)
    
    # extract first result and use pd.set_value to insert into dataframe
    results = response.get('results')
    if (results):
        restr = response['results'][0]
        print(f"Closest {restr_type} restaurant is {restr.get('name', 'Unknown')}.")
        types_df.loc[index, 'name'] = restr.get('name', '')
        types_df.loc[index, 'address'] = restr.get('vicinity', '')
        types_df.loc[index, 'price_level'] = restr.get('price_level', '')
        types_df.loc[index, 'rating'] = restr.get('rating', '')
    else:
        print("No results for " + restr_type)
    print("------------")
# Out:
# Retrieving Results for Index 0: chinese.
# Closest chinese restaurant is Su Xing House.
# ------------
# Retrieving Results for Index 1: cuban.
# Closest cuban restaurant is Alma de Cuba.
# ------------
# Retrieving Results for Index 2: czech.
# Closest czech restaurant is Subway Restaurants.
# ------------
# Retrieving Results for Index 3: french.
# Closest french restaurant is Amuse.
# ------------
# Retrieving Results for Index 4: german.
# Closest german restaurant is Brü Craft & Wurst.
# ------------
# Retrieving Results for Index 5: greek.
# Closest greek restaurant is Noon Mediterranean.
# ------------
# Retrieving Results for Index 6: haitian.
# Closest haitian restaurant is Coconut Breeze Cuisine.
# ------------
# Retrieving Results for Index 7: hungarian.
# Closest hungarian restaurant is Wursthaus Schmitz.
# ------------
# Retrieving Results for Index 8: indian.
# Closest indian restaurant is Cafe Spice Express - Online Ordering, Restaurant & Catering.
# ------------
# Retrieving Results for Index 9: indonesian.
# Closest indonesian restaurant is Banana Leaf: Malaysian Cuisine.
# ------------
# Retrieving Results for Index 10: irish.
# Closest irish restaurant is Tir na nOg Irish Bar & Grill.
# ------------
# Retrieving Results for Index 11: israeli.
# Closest israeli restaurant is Goldie.
# ------------
# Retrieving Results for Index 12: italian.
# Closest italian restaurant is Davio's Northern Italian Steakhouse.
# ------------
# Retrieving Results for Index 13: japanese.
# Closest japanese restaurant is Double Knot.
# ------------
# Retrieving Results for Index 14: jewish.
# Closest jewish restaurant is R2L Restaurant.
# ------------
# Retrieving Results for Index 15: korean.
# Closest korean restaurant is Giwa - Fresh Korean Kitchen.
# ------------
# Retrieving Results for Index 16: lebanese.
# Closest lebanese restaurant is Boutros Greek & Middle Eastern.
# ------------
# Retrieving Results for Index 17: mexican.
# Closest mexican restaurant is Chipotle Mexican Grill.
# ------------
# Retrieving Results for Index 18: new american.
# Closest new american restaurant is Square 1682.
# ------------
# Retrieving Results for Index 19: pakistani.
# Closest pakistani restaurant is Indeblue Restaurant and Bar.
# ------------
# Retrieving Results for Index 20: polish.
# Closest polish restaurant is Franks A-lot.
# ------------
# Retrieving Results for Index 21: russian.
# Closest russian restaurant is Rachael's Nosheri.
# ------------
# Retrieving Results for Index 22: scandinavian.
# Closest scandinavian restaurant is Hotel Sofitel Philadelphia.
# ------------
# Retrieving Results for Index 23: scottish.
# No results for scottish
# ------------
# Retrieving Results for Index 24: soul food.
# Closest soul food restaurant is Keven Parker's Soul Food Cafe.
# ------------
# Retrieving Results for Index 25: spanish.
# Closest spanish restaurant is Jamonera.
# ------------
# Retrieving Results for Index 26: thai.
# Closest thai restaurant is Xiandu Thai Fusion Cuisine.
# ------------
# Retrieving Results for Index 27: turkish.
# Closest turkish restaurant is The Original Turkey.
# ------------
# Retrieving Results for Index 28: ukrainian.
# Closest ukrainian restaurant is The Pierogie Kitchen.
# ------------
# Retrieving Results for Index 29: vietnamese.
# Closest vietnamese restaurant is Vietnam Express.
# ------------

# %%
types_df
# Out:
#        ethnicity                                               name  \
# 0        chinese                                      Su Xing House
# 1          cuban                                       Alma de Cuba
# 2          czech                                 Subway Restaurants
# 3         french                                              Amuse
# 4         german                                  Brü Craft & Wurst
# 5          greek                                 Noon Mediterranean
# 6        haitian                             Coconut Breeze Cuisine
# 7      hungarian                                  Wursthaus Schmitz
# 8         indian  Cafe Spice Express - Online Ordering, Restaura...
# 9     indonesian                     Banana Leaf: Malaysian Cuisine
# 10         irish                       Tir na nOg Irish Bar & Grill
# 11       israeli                                             Goldie
# 12       italian                Davio's Northern Italian Steakhouse
# 13      japanese                                        Double Knot
# 14        jewish                                     R2L Restaurant
# 15        korean                        Giwa - Fresh Korean Kitchen
# 16      lebanese                     Boutros Greek & Middle Eastern
# 17       mexican                             Chipotle Mexican Grill
# 18  new american                                        Square 1682
# 19     pakistani                        Indeblue Restaurant and Bar
# 20        polish                                       Franks A-lot
# 21       russian                                  Rachael's Nosheri
# 22  scandinavian                         Hotel Sofitel Philadelphia
# 23      scottish
# 24     soul food                      Keven Parker's Soul Food Cafe
# 25       spanish                                           Jamonera
# 26          thai                         Xiandu Thai Fusion Cuisine
# 27       turkish                                The Original Turkey
# 28     ukrainian                               The Pierogie Kitchen
# 29    vietnamese                                    Vietnam Express
#
#                                    address price_level rating
# 0             1508 Sansom St, Philadelphia           1    4.5
# 1             1623 Walnut St, Philadelphia           3    4.4
# 2             1515 Market St, Philadelphia           1    4.2
# 3               1421 Arch St, Philadelphia           4    4.5
# 4           1316 Chestnut St, Philadelphia           2      4
# 5             1601 Market St, Philadelphia                3.8
# 6                    708 Church Ln, Yeadon           2    3.9
# 7               51 N 12th St, Philadelphia                3.3
# 8             1700 Market St, Philadelphia                  3
# 9               1009 Arch St, Philadelphia           2    4.1
# 10              1600 Arch St, Philadelphia           2    4.1
# 11            1526 Sansom St, Philadelphia           1    4.7
# 12             111 S 17th St, Philadelphia           3    4.5
# 13             120 S 13th St, Philadelphia           2    4.7
# 14   50 S 16th St 37th floor, Philadelphia           3    4.4
# 15            1722 Sansom St, Philadelphia           2    4.4
# 16            200 S Broad St, Philadelphia           1
# 17          1625 Chestnut St, Philadelphia           1    3.3
# 18             121 S 17th St, Philadelphia           3      4
# 19             205 S 13th St, Philadelphia           2    4.4
# 20              51 N 12th St, Philadelphia                2.4
# 21       4629, 120 S 19th St, Philadelphia           1      4
# 22             120 S 17th St, Philadelphia                4.5
# 23
# 24       N 12th St & Arch St, Philadelphia                3.6
# 25             105 S 13th St, Philadelphia           2    4.3
# 26            1119 Walnut St, Philadelphia           2    4.6
# 27              45 N 12th St, Philadelphia           1    4.2
# 28  1709, 648 Roxborough Ave, Philadelphia           1    4.2
# 29             106 S 20th St, Philadelphia                4.5

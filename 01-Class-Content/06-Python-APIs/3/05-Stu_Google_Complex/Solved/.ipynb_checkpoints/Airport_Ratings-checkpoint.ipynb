# %%
# Dependencies
import pandas as pd
import numpy as np
import requests
import json

# Google API Key
from config import gkey

# %%
# Import cities file as DataFrame
cities_pd = pd.read_csv("../Resources/cities.csv")
cities_pd.head()
# Out:
#             City         State
# 0  New York City      New York
# 1    Los Angeles    California
# 2        Chicago      Illinois
# 3        Houston         Texas
# 4   Philadelphia  Pennsylvania

# %%
# Add columns for lat, lng, airport name, airport address, airport rating
# Note that we used "" to specify initial entry.
cities_pd["Lat"] = ""
cities_pd["Lng"] = ""
cities_pd["Airport Name"] = ""
cities_pd["Airport Address"] = ""
cities_pd["Airport Rating"] = ""
cities_pd.head()
# Out:
#             City         State Lat Lng Airport Name Airport Address  \
# 0  New York City      New York
# 1    Los Angeles    California
# 2        Chicago      Illinois
# 3        Houston         Texas
# 4   Philadelphia  Pennsylvania
#
#   Airport Rating
# 0
# 1
# 2
# 3
# 4

# %%
# create a params dict that will be updated with new city each iteration
params = {"key": gkey}

# Loop through the cities_pd and run a lat/long search for each city
for index, row in cities_pd.iterrows():
    base_url = "https://maps.googleapis.com/maps/api/geocode/json"

    city = row['City']
    state = row['State']

    # update address key value
    params['address'] = f"{city},{state}"

    # make request
    cities_lat_lng = requests.get(base_url, params=params)
    #print(cities_lat_lng)
    # print the cities_lat_lng url, avoid doing for public github repos in order to avoid exposing key
    print(cities_lat_lng.url)
    
    # convert to json
    cities_lat_lng = cities_lat_lng.json()
    #print(cities_lat_lng)
    cities_pd.loc[index, "Lat"] = cities_lat_lng["results"][0]["geometry"]["location"]["lat"]
    cities_pd.loc[index, "Lng"] = cities_lat_lng["results"][0]["geometry"]["location"]["lng"]

# Visualize to confirm lat lng appear
cities_pd.head()
# Out:
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=New+York+City%2CNew+York
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Los+Angeles%2CCalifornia
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Chicago%2CIllinois
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Houston%2CTexas
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Philadelphia%2CPennsylvania
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Phoenix%2CArizona
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=San+Antonio%2CTexas
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=San+Diego%2CCalifornia
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Dallas%2CTexas
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=San+Jose%2CCalifornia
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Austin%2CTexas
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Jacksonville%2CFlorida
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=San+Francisco%2CCalifornia
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Indianapolis%2CIndiana
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Columbus%2COhio
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Fort+Worth%2CTexas
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Charlotte%2CNorth+Carolina
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Seattle%2CWashington
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Denver%2CColorado
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=El+Paso%2CTexas
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Detroit%2CMichigan
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Washington%2CDistrict+of+Columbia
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Boston%2CMassachusetts
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Memphis%2CTennessee
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Nashville%2CTennessee
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Portland%2COregon
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Oklahoma+City%2COklahoma
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Las+Vegas%2CNevada
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Baltimore%2CMaryland
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Louisville%2CKentucky
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Milwaukee%2CWisconsin
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Albuquerque%2CNew+Mexico
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Tucson%2CArizona
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Fresno%2CCalifornia
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Sacramento%2CCalifornia
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Kansas+City%2CMissouri
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Long+Beach%2CCalifornia
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Mesa%2CArizona
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Atlanta%2CGeorgia
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Colorado+Springs%2CColorado
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Virginia+Beach%2CVirginia
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Raleigh%2CNorth+Carolina
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Omaha%2CNebraska
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Miami%2CFlorida
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Oakland%2CCalifornia
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Minneapolis%2CMinnesota
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Tulsa%2COklahoma
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Wichita%2CKansas
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=New+Orleans%2CLouisiana
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Arlington%2CTexas
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Cleveland%2COhio
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Bakersfield%2CCalifornia
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Tampa%2CFlorida
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Aurora%2CColorado
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Honolulu%2CHawai%27i
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Anaheim%2CCalifornia
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Santa+Ana%2CCalifornia
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Corpus+Christi%2CTexas
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Riverside%2CCalifornia
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=St.+Louis%2CMissouri
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Lexington%2CKentucky
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Stockton%2CCalifornia
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Pittsburgh%2CPennsylvania
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Saint+Paul%2CMinnesota
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Anchorage%2CAlaska
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Cincinnati%2COhio
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Henderson%2CNevada
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Greensboro%2CNorth+Carolina
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Plano%2CTexas
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Newark%2CNew+Jersey
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Toledo%2COhio
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Lincoln%2CNebraska
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Orlando%2CFlorida
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Chula+Vista%2CCalifornia
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Jersey+City%2CNew+Jersey
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Chandler%2CArizona
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Fort+Wayne%2CIndiana
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Buffalo%2CNew+York
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Durham%2CNorth+Carolina
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=St.+Petersburg%2CFlorida
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Irvine%2CCalifornia
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Laredo%2CTexas
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Lubbock%2CTexas
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Madison%2CWisconsin
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Gilbert%2CArizona
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Norfolk%2CVirginia
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Reno%2CNevada
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Winston-Salem%2CNorth+Carolina
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Glendale%2CArizona
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Hialeah%2CFlorida
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Garland%2CTexas
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Scottsdale%2CArizona
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Irving%2CTexas
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Chesapeake%2CVirginia
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=North+Las+Vegas%2CNevada
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Fremont%2CCalifornia
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Baton+Rouge%2CLouisiana
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Richmond%2CVirginia
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=Boise%2CIdaho
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDqyiML69kxTbKolq63B1GhFaP_VL5CEP0&address=San+Bernardino%2CCalifornia
#             City         State      Lat      Lng Airport Name Airport Address  \
# 0  New York City      New York  40.7128  -74.006
# 1    Los Angeles    California  34.0522 -118.244
# 2        Chicago      Illinois  41.8781 -87.6298
# 3        Houston         Texas  29.7604 -95.3698
# 4   Philadelphia  Pennsylvania  39.9526 -75.1652
#
#   Airport Rating
# 0
# 1
# 2
# 3
# 4

# %%
# params dictionary to update each iteration
params = {
    "radius": 50000,
    "types": "airport",
    "keyword": "international airport",
    "key": gkey
}

# Use the lat/lng we recovered to identify airports
for index, row in cities_pd.iterrows():
    # get lat, lng from df
    lat = row["Lat"]
    lng = row["Lng"]

    # change location each iteration while leaving original params in place
    params["location"] = f"{lat},{lng}"

    # Use the search term: "International Airport" and our lat/lng
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # make request and print url
    name_address = requests.get(base_url, params=params)
    
#     print the name_address url, avoid doing for public github repos in order to avoid exposing key
#     print(name_address.url)

    # convert to json
    name_address = name_address.json()
    print(json.dumps(name_address, indent=4, sort_keys=True))

    # Since some data may be missing we incorporate a try-except to skip any that are missing a data point.
    try:
        cities_pd.loc[index, "Airport Name"] = name_address["results"][0]["name"]
        cities_pd.loc[index, "Airport Address"] = name_address["results"][0]["vicinity"]
        cities_pd.loc[index, "Airport Rating"] = name_address["results"][0]["rating"]
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
# Out:
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 40.6895314,
#                     "lng": -74.1744624
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 40.69546885,
#                         "lng": -74.1670314
#                     },
#                     "southwest": {
#                         "lat": 40.68755225000001,
#                         "lng": -74.1967554
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png",
#             "id": "8d57add005d7717b94e463fe24b9825cdd909afc",
#             "name": "Newark Liberty International Airport",
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110179936954015331547/photos\">Gregory P</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAQdEK3vRgq57_C5hUoSlXev0LTPWb_DiET3aJ0jGDP109RCucp4rZdHmKQSCvyMNCxkSncccsBAhw6kbTfU-QguGtjzNYG5rPNEUsTXaa_e3qB_P0xkVo6p3SvVFoaERNEhB5VImEMubRHVaT8szHRhJ6GhSCevXQth5PQt0X67Ez7SjYA8BNVw",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJ7wzsxeFSwokRhvLXxTe087M",
#             "rating": 3.2,
#             "reference": "CmRbAAAAwRiMNbDASPErKZa57b9O_OQ7aLuPMqbDgv7zLyg0ERigmt_rZp28qKRxT-YZ7exKA5MamLjDohqG_M_2c8ZfPe8WNR7UJ7Ve2ilO6YM0NwGkr2Ce1ZAnLml8lNZSkbrUEhCBo_OXyYNx2bF0KxB__gZ6GhTUqM_Ct2DZddMcQm0GaMjtm8j5BA",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "3 Brewster Rd, Newark"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 40.6413111,
#                     "lng": -73.77813909999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 40.6635108,
#                         "lng": -73.76341895
#                     },
#                     "southwest": {
#                         "lat": 40.63391119999999,
#                         "lng": -73.82229955000001
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png",
#             "id": "87586c86ef1c53323d31eba8260ca7f0ea7cb094",
#             "name": "John F. Kennedy International Airport",
#             "photos": [
#                 {
#                     "height": 3000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104198955763677338861/photos\">\u65b0\u83ef\u8a31</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAS1fGtm4ECbCzL0be_hn1V_DLkFQZo-IGaX04ODvUXYFB_FwoUCZR2LnIjA9ObshkcYrMvh3vPYEch52pULJ8uOsvrdIMZkgNLA9oTfokjI7lCpqQ0EDNHE9r6C67xwCXEhBF4yrleTPMaapP3VeYXDa_GhSUNlp0v6zYOnEKbFFWX5AsF1YMAw",
#                     "width": 5332
#                 }
#             ],
#             "place_id": "ChIJR0lA1VBmwokR8BGfSBOyT-w",
#             "rating": 3.8,
#             "reference": "CmRbAAAAHR7Nc7SViniXAlsAhIBM6SbjBBdHVBohm84mKmQLBlhAFN4yctVDKa6bEi8RnZs8Av8QABngngXCYrlKEUbciORDskZ-J8gTVsaLMKsRITFMEu9LhWLMHKIWeniL2n8hEhAzGO1xQS9zE6ETVcRaJ3z0GhQ3Cxcu42C_f7tyCb96d7ntn-dElw",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Queens"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 40.7769271,
#                     "lng": -73.8739659
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 40.7796712,
#                         "lng": -73.87067474999998
#                     },
#                     "southwest": {
#                         "lat": 40.76869480000001,
#                         "lng": -73.87506295000001
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png",
#             "id": "f8eabf71af15bb6c56ec923bf2e475ca3a39f3b2",
#             "name": "LaGuardia Airport",
#             "photos": [
#                 {
#                     "height": 960,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112128678731388920770/photos\">Renee Ira</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAcA67jw6z6B1U0-NL6psBKeRE8VWM2NBHB8HVTer7kFxnaTv9shH5uuc8xTYlI7XrU6Qt5EnpR2h2svR1plUiuY8XHIPl0tQIzOX4fP8KAox4FNMaRZwE5G9qgeAE-mesEhBa02zi2GHONuITL_gg3q-9GhTbioWvPwRrZnZUVjiKhfzdQf7KlQ",
#                     "width": 1280
#                 }
#             ],
#             "place_id": "ChIJtU1Cg4lfwokRs2aWDmbEL3c",
#             "rating": 2.8,
#             "reference": "CmRbAAAA96K0hWmizEfdW-S99U_xirmNBoeNjvuAHj8c69vl3xIYt3Rke0mpWjrlinpio-TTJZGlQ2UPN5nDQiq7TKeljRy5YCxQh61-pLTNa6id45jqOR2l6SY1UPAgkGXPxQwsEhB9E9xkVoKSaxnbHJJaQnIJGhS6k1U3REEO1s1-tyFd13RRsJ1W7g",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Queens"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.0683325,
#                     "lng": -73.7086641
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.0746118,
#                         "lng": -73.70437935000001
#                     },
#                     "southwest": {
#                         "lat": 41.06623939999999,
#                         "lng": -73.71009234999998
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png",
#             "id": "926f7656bd53d39eb22c151d4b5ccf21c04f821a",
#             "name": "Westchester County Airport",
#             "opening_hours": {
#                 "open_now": true,
#                 "weekday_text": []
#             },
#             "photos": [
#                 {
#                     "height": 2988,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102055379888537794634/photos\">Mark Kemper</a>"
#                     ],
#                     "photo_reference": "CmRaAAAASuvTIyX42MGLDRFKwg_gQB-mUAKcjJHCKn8CziDSL6N-4ynTgX0p3bcfUUeo03dyXEG8UGJUnYxPdLVLvs3HYFpddJ7dehT6m_MXKIsPyYqlbOJz4oZRE64CijzIzBYtEhC6E1hsto1kjnAxoEPjq1mDGhRsWybF5ww-zfkdGJVn9AmaXE2G-w",
#                     "width": 5312
#                 }
#             ],
#             "place_id": "ChIJdZWrbymWwokRbck_om4HQ80",
#             "rating": 4,
#             "reference": "CmRbAAAAOGMRCmb6seszrV0Q0k8NcTrUiZ38wcqy9ISXoVBd1V7mCVI6BcAsCkL3bZlPeHF6Ck8y29WJ4WsHLzb9-bzCHrmiiLOWUZDMcja8aN_fmfiHIObN2bHwYb4T3TCzSIWlEhAoJCv6KJPXf4eedDTf5mSKGhQoMRR0mWNrIx0liix2fyd3Gm2wQw",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "240 Airport Rd, White Plains"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 40.6439568,
#                     "lng": -73.7823317
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 40.64530662989272,
#                         "lng": -73.78098187010728
#                     },
#                     "southwest": {
#                         "lat": 40.64260697010728,
#                         "lng": -73.78368152989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png",
#             "id": "57101d032a48489e9f024fb7562bbd61a84604bb",
#             "name": "JFK International Airport, Terminal 4",
#             "photos": [
#                 {
#                     "height": 3456,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107940185863834141395/photos\">Reino Hornson</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAd9S3FULx2zwDohrYSFYBzAvnMLUq82F2aN2HTyTCAwpe0BeY0ZOLx01US-FPXwbhmBdknQ4cqgiWmSbzbN-FkWcke-BCKGHi5WdHfkTYZ5RH7Z-LibDBf-GbxpOS2u60EhC11r6vamu_4Sgwl-wnGMrXGhQdHl0u_ImlNR_6fqc7rnEtiiWNnQ",
#                     "width": 4608
#                 }
#             ],
#             "place_id": "ChIJbcKrxFlmwokRgqcvzU_pG2E",
#             "rating": 2.6,
#             "reference": "CmRbAAAA89Q19vdy5bZETtBfgqMiJ5iWawgPlw3IxKlgLlLA5ZI_LAaBb2PP4wHmHRO3RrHvv7xNHD4HsgH51bpFOZbSRfe0gOj4VRQmttCmplDeU5KH04C4RhK3Fc99xTu0T-eYEhBMuK8SHrhOm4rrr2zIuxVPGhR4-Pgz9Rcb9uqTlrvee58JFuZ9Iw",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Jamaica"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 40.6903683,
#                     "lng": -74.1775846
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 40.69171812989272,
#                         "lng": -74.17623477010729
#                     },
#                     "southwest": {
#                         "lat": 40.68901847010728,
#                         "lng": -74.17893442989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png",
#             "id": "2a820cf3b5e95afd14925f32ba726282f9d01644",
#             "name": "Newark international airport",
#             "photos": [
#                 {
#                     "height": 2160,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106472410092455186152/photos\">\u3084\u307e\u3042\u3044</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA5Xi5wtdJrpuqSJOVGsrMYb-Kdy-R2VBfIkxbHyq3GgAkHk0LH-tDLlymBy75bq28oYWILrZ-tdc_gssWa9u2UxN2XhmOQOE6afkndVFXPdu_9KKHxkvlc3p9VrYVskYDEhDWps5kW0jdTZ-JzTcSS9h7GhT-Z28QlIMnXhpLZPA4Dg4IDNdUOw",
#                     "width": 3840
#                 }
#             ],
#             "place_id": "ChIJ_Qpf5L5TwokRBBlhAxzivp0",
#             "rating": 4,
#             "reference": "CmRbAAAAlKddvTibdorzfaU7WetrPTb4bw-ZHKDn_XCsdvPTJysJym9pjWCqJXBLUTKbmwtZR7TIEcjFK708Vt6G-qfRx86spYldvf3qkGzcB_BSRBDtO5N3zhA-afhepDtmPQO_EhAG4-_mciv5e4ixyKgjsCbyGhRw21cnJF6GDkcRoT6YivoYB6iLmA",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "US-1 Truck, Newark"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 40.6917106,
#                     "lng": -74.17460969999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 40.69306042989272,
#                         "lng": -74.17325987010727
#                     },
#                     "southwest": {
#                         "lat": 40.69036077010728,
#                         "lng": -74.17595952989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png",
#             "id": "9a3c18c331fc6d7613e1236dd67834850bebb9fc",
#             "name": "SAS Business Lounge, Newark International Airport",
#             "opening_hours": {
#                 "open_now": false,
#                 "weekday_text": []
#             },
#             "photos": [
#                 {
#                     "height": 2448,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105906484344105714990/photos\">John Henrik Morstad</a>"
#                     ],
#                     "photo_reference": "CmRaAAAATByo-xq-jjWvNHE_pYz9mUpfPLsfQwGU-lZ18zwEEnH3QY8g5SNAZ48_ap9vlMdjtcOqfQsvBFTmyC8dsFqKpaDga-Y3-yuYzT0wo3U0U1qer4f7Y28ru6gRM9TP0sznEhAZl8e7KXvVT_-XLS0bNmLCGhTlteURT5KVIUIQ1KB9aPJHYNpdRw",
#                     "width": 3264
#                 }
#             ],
#             "place_id": "ChIJEUaEDfdSwokRKs35RtAQNk4",
#             "rating": 3.6,
#             "reference": "CmRbAAAAgNT2mfR3rXJK5_SKJCz1mclZ2VEcAzZa3Fkr6CDOi1DvQd0YlZRlPTywazeDJFkfp4OWFm0dsrinoHGM3RfpKbTAWAfS5rQyDXY5fZqv2Zl9VVG8y6B10oU_IJtjqMeoEhC0XgiQ6UYFJ2WrxdIEnyxMGhSsZROX7NwdBRhaqKW-uGZyeuhFdA",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Newark"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 40.6541843,
#                     "lng": -73.8088691
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 40.65553412989271,
#                         "lng": -73.80751927010728
#                     },
#                     "southwest": {
#                         "lat": 40.65283447010727,
#                         "lng": -73.81021892989271
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png",
#             "id": "4f651e06a22bdb0c19d449c58f09a696f8c15ba0",
#             "name": "Swissport",
#             "place_id": "ChIJk7O8-ghnwokRTs3A3NU7Gx4",
#             "rating": 2.7,
#             "reference": "CmRbAAAAm-EOs1uD8s6yhvayzSS5dkjSvaW02x1UsyDmWlXcJXpdbcmHZwpMOd6z9rsf5xveXTFpDDc7IVTpb5gKvfnvlS5AA4PP0i1gCLw5YzIcAukpN93zvnXCot2ueEbH1kBZEhAlfjO65kV7U2CIXiaoJ5e3GhSNe-GEq6LZQSo-j8mRHbBJ3BcUNQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Jamaica"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 40.7070848,
#                     "lng": -74.1699593
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 40.70889207989271,
#                         "lng": -74.16858377010729
#                     },
#                     "southwest": {
#                         "lat": 40.70619242010727,
#                         "lng": -74.17128342989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png",
#             "id": "861d9164200e0edebd0f1e57ed55e8d7cd008b93",
#             "name": "Signature Flight Support EWR - Newark Liberty Int'l Airport",
#             "opening_hours": {
#                 "open_now": true,
#                 "weekday_text": []
#             },
#             "photos": [
#                 {
#                     "height": 2496,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101904338275378088280/photos\">Signature Flight Support EWR - Newark Liberty Int&#39;l Airport</a>"
#                     ],
#                     "photo_reference": "CmRaAAAArkzg10NkCE4qom_EGYZPbn90CZC4f1ORsBOAQaUzMCdweyf-gSRMudmY0LtHsprRUOIViflw8MlnYmzonRkKbV1fMZAavt0dcs3Iub-Z9aqU7_u3bHdMNv559iJDPvnmEhCDAXgKqzU0K58jpaDQVIfkGhT774znKNz5M-w6VASOCkLzfnoN8g",
#                     "width": 3500
#                 }
#             ],
#             "place_id": "ChIJQ1vCuu9SwokRWtpm5NQb0Oc",
#             "rating": 3.8,
#             "reference": "CmRbAAAAzhjYR_US5X45sQ7vkv-jwLV3k6gIL62d7Ix9FdNrYmfz6qLi1uCmkTlLtT6G363P8P2nQPa6BaNh0llQ9kHhNmaxwEtS0aQwF_eZhgTxrblBmvplzBgL2mSZiF0bum2xEhDD0WlfPh3lGBOVhZFPpNRTGhQ652igAjIWyAkYPTbGGzzLYqluQQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "premise",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "15 Brewster Rd, Newark"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 40.6936441,
#                     "lng": -74.18182150000001
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 40.69495027989272,
#                         "lng": -74.18036532010728
#                     },
#                     "southwest": {
#                         "lat": 40.69225062010727,
#                         "lng": -74.18306497989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png",
#             "id": "9fc25e201a4ca4281c03b0758941740c91c09035",
#             "name": "Avis Car Rental",
#             "place_id": "ChIJx2WuD_BSwokRGDO5rhNKR00",
#             "rating": 2,
#             "reference": "CmRbAAAAd1f9QAt9XIGynNCrbAWqfIbzZVFZ_53RbKcyIC1ClU9l3ZK3ge2TLlyi9pjtuOJHlvXyFRfhwUOprDn3hNHbVdHAs6oFSsyX1sUTFGVrTBSfNUFE8yiNI0Pbrg822b9TEhB2Pg9OdExzLIyTZYjTSFvHGhSEucEucogXzEhCga4tD1hMqcMesw",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Newark International Airport St, Newark"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 40.7350747,
#                     "lng": -74.17390569999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 40.73642452989272,
#                         "lng": -74.17255587010727
#                     },
#                     "southwest": {
#                         "lat": 40.73372487010728,
#                         "lng": -74.17525552989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png",
#             "id": "2fedcbe7be5d316996ef0b0e837d1b25b5b4c731",
#             "name": "Relay Newark International Airport",
#             "place_id": "ChIJVVVVVXhTwokRjXPyHO7fqoM",
#             "rating": 5,
#             "reference": "CmRbAAAAxyV_xV5Kxio7xrQ32SVbdNtXQyP6f1NEHH9Dg_hxOWTBZMVxrGyaQGa0tYe5mnURHavNMqd9gMp7yKfrkJtgNti3MOB2XdmD-9UQ-WOyq_CBj6VFd4KSH3sO6VUvVAjuEhC3rihG95A1fSRljetXXT3BGhTSn5n8yntzDdV0PfGFo3CIpM88jw",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Newark"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 40.7233887,
#                     "lng": -73.5875694
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 40.72481952989273,
#                         "lng": -73.58580277010728
#                     },
#                     "southwest": {
#                         "lat": 40.72211987010729,
#                         "lng": -73.58850242989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png",
#             "id": "56c2ce4cf6643ae26a557d8ada36a441221c433e",
#             "name": "JFK Airport",
#             "place_id": "ChIJq6qq85N9wokRyBLAdJUvxwM",
#             "reference": "CmRbAAAAQIegTY3ffV8OnY2tdVjdfCR87kQEJu_RS_mfCmy6ftxzZJuXbxve8uy35dUYmlE7uSELjs9ZoPowUemLWRWCyjNuZngUjZSq-K-4nsAtfIAO7_53Vn4UCIwZI8bau_FeEhCjZ0l-rJ42jIRWDs45NegqGhTfYIYKJQblR5gComyP5dlurmaaEw",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "101 James Doolittle Blvd, Uniondale"
#         }
#     ],
#     "status": "OK"
# }
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 33.9415889,
#                     "lng": -118.40853
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.95273285,
#                         "lng": -118.384788
#                     },
#                     "southwest": {
#                         "lat": 33.93787425,
#                         "lng": -118.416444
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png",
#             "id": "2b1ad644609c86ef8156eeec48a4675d580224d9",
#             "name": "Los Angeles International Airport",
#             "photos": [
#                 {
#                     "height": 1490,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114118451392288609524/photos\">Pako Valera</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAu184FBeF77_GGIiQy5MSV8kdQ_7KhoRJRzNB7PrqnJldJvUatg_3UWMLIq-XLJMOHelj1VMNCuIgokvlO9VavgqiDBaxS79s7GQ3IPMefIpTSGFTjPJNm8sAmqPCl1eFEhDbEnqSpuNnthssuAktNlccGhS7YwZgSOiKTJ3ppRZk-h4nR0RiVg",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJtU-yE9KwwoAR8a2LaVd7qHc",
#             "rating": 3.6,
#             "reference": "CmRbAAAAZXMu-BuNgZPlPUFXNxwwx0-WMp8QNE-3lT1NI91TnuYX137k1PXRXRU5rWQLIJfIRrGU-fK3zu9WFvfSeViTZJHc8FFO4aXlAMkmV7RDDtC8ZOtx9MZDfNUW4LZ3pUVEEhA7CZDYaCjYU5XWN3pDYMezGhRh6BRvnVlVAd408nDJC6WzrEg3Xg",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "1 World Way, Los Angeles"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 33.9526866,
#                     "lng": -118.3668015
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.95400872989272,
#                         "lng": -118.3652608201073
#                     },
#                     "southwest": {
#                         "lat": 33.95130907010728,
#                         "lng": -118.3679604798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png",
#             "id": "fe7ec2bf4b8fd6d268f0126a53b5bb6a7ca7f595",
#             "name": "Lax Airport",
#             "photos": [
#                 {
#                     "height": 3006,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116678667724313414714/photos\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAhOUYWIpUAlbxWFIqyyL21bTuEYn3mR9esQR1pAQQ_ImGFin5Xv30u8CfJtDv5wjCqqEz-Pdr8y-Q62jwSfC_be09GSLjaBdkkubq-Z7gFZOQCHLeZ6Bt_mdAbK_mMwAFEhDQzBiO4hiFrX7gccN0asZ6GhT9QDUvLvJgcr7GY1zxOJCnPhG4zw",
#                     "width": 5344
#                 }
#             ],
#             "place_id": "ChIJX5R7VeC2woARljTmye6Xz9w",
#             "reference": "CmRbAAAA7OoAex-_dXWOj9xIRyezFYTpVvV5rR95OumD-wQuQsHOc5_E_DstmBzj2TyPDJYRDCoOdS1ZyTIN5QGs9TGhbpopdmqtyxGOu0S-CX-5HZFWq6bWvwV4tf2Qv3sXln8CEhDCasde8Ot7jW-l5eSF_IHIGhRIcE8KJe6pevn-oeMJP8jFE1oVQA",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Arbor Vitae St, Inglewood"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 33.9335432,
#                     "lng": -118.3955997
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.93489302989272,
#                         "lng": -118.3942498701073
#                     },
#                     "southwest": {
#                         "lat": 33.93219337010728,
#                         "lng": -118.3969495298928
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png",
#             "id": "c8366e5077abe613f49b5fe1e7634952610e3ac9",
#             "name": "Signature Flight Support LAX - Los Angeles International Airport",
#             "opening_hours": {
#                 "open_now": true,
#                 "weekday_text": []
#             },
#             "photos": [
#                 {
#                     "height": 1536,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105404442529085180539/photos\">Signature Flight Support LAX - Los Angeles International Airport</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAZ6iw6cki6ET8YFvxAUPjY9DxoJ7MTX-zhYnolxOOWZPR9KO-9pS4gLo-9ushTjUIW533P5pbXj15rwYhd5et5brGWNhRG9LMoOt8DtrYf7ih9IMsJbqYOdvE6-iNeyFzEhD0TKcANEle1qnlu1ToG-JTGhRUu8t8OLPPMyn7goHMfGhpCzEa_A",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJD8frczOxwoAR5yL-qXAxaHw",
#             "rating": 2,
#             "reference": "CmRbAAAAOJGXXTLV8uHLJ9erKjCxZLvdfwQ4aJ3kYsULjCjXjGPBwU5grvjq5eJo7PCy_tbZofF9e1som3mPqmoTzKS5CSIdvwU1yEx2KF01XvhoGxXm29wLRAoOgH8-zIAUxAeHEhDRC6pl5XkXKlto4PJPSf92GhRo1dW51pCg_Q42aZnKgM0EbCDRrg",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "6201 W Imperial Hwy, Los Angeles"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 33.96822030000001,
#                     "lng": -118.4210571
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.96957012989272,
#                         "lng": -118.4197072701073
#                     },
#                     "southwest": {
#                         "lat": 33.96687047010728,
#                         "lng": -118.4224069298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png",
#             "id": "3139264d3be90cb2116b38915e05f9d4062e42ad",
#             "name": "Los Angeles International Airport",
#             "photos": [
#                 {
#                     "height": 1536,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115027288387975928704/photos\">Alan Chen</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAcZA8goeytqphJJARv9ELyI5mLNcj7pGEZ6ohTZukPsiCIew9X7UjV0FZigpz3U_gg9Ra5ODywmZkNQ521PVWu5HjzBKqTo-OEIk4SF50d9b2rfmK8WVVS8FrJ5PLp4PSEhB8L4I47qCyTeOx8j1yEnQuGhQmcIB9xSnNTL6PdzVzfE59VbZh7A",
#                     "width": 2370
#                 }
#             ],
#             "place_id": "ChIJmzRVuZawwoARh_YL8ZBP2Es",
#             "reference": "CmRbAAAAcVwGVvJ7BjW7yUpNNuY46oAT-nAkD7gvumKQQ8hw9HJSYJxy4mzjpiXe69-9lCxr4OnYcnQCdIX3lEIUhTxZM1nsmT1k7kRqMKKHRFTTKhoP10mAhmIWLvgaYuu25fqSEhArTLVUG4GQpb_sHLNL7bKdGhQ8A0UX6A8tg5U-CoUjhXeggs82sA",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Los Angeles"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 33.9439886,
#                     "lng": -118.4093193
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.94540492989272,
#                         "lng": -118.4074321701073
#                     },
#                     "southwest": {
#                         "lat": 33.94270527010728,
#                         "lng": -118.4101318298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png",
#             "id": "3a370f72eb83efda2e8a9d2b511c47cf97f7fa83",
#             "name": "Total Airport Services",
#             "photos": [
#                 {
#                     "height": 996,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117390329405935162394/photos\">Louis Chibbaro</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAAmtAZLeBfjaRrJSOA2mzd0xN6JDvp380Y1eVgAPP-Scsz1tNnPxXSPyJrlD83o8_DGovmYykvEBqQXf9VIi6vjyKtHLs6uYPRCP1ODMHu4qQOFMcdXttRY_xHensitKrEhBnunI9p-F_fFRzRmJ_VFnIGhTotsoew9TIW0KDOk5WMrqAHdxKvA",
#                     "width": 739
#                 }
#             ],
#             "place_id": "ChIJdwO4QiexwoARewC5JUuKvUs",
#             "rating": 5,
#             "reference": "CmRbAAAA3SCmkSYZy4dTJQt13MUTFiwzkcWZRLg5QWEYY-vwH2gzbwhQAdiIDiVpBqM1coAo9UtOzIF2lauB1deqyd9qLz_a4e_YPNmEgAP7xSmi9YkyEqeZZcnopAleLgLpiWPbEhCMwPLc3lsu4GRpCufIfpqnGhTWgOmsDOEPyS395znWVVXyNhBs9A",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "1 World Way, Los Angeles"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 34.1963937,
#                     "lng": -118.3540925
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 34.19771552989273,
#                         "lng": -118.3527067201072
#                     },
#                     "southwest": {
#                         "lat": 34.19501587010728,
#                         "lng": -118.3554063798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png",
#             "id": "408d8d3ada31ac6855f05794c7b516d48ba18cea",
#             "name": "Terminal A Baggage Claim",
#             "opening_hours": {
#                 "open_now": true,
#                 "weekday_text": []
#             },
#             "photos": [
#                 {
#                     "height": 2988,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101369752284015892943/photos\">Kurt Kirkland</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAtFN2mYyGUb6SKQn48bIvCUTb8j8-8T_lrqrdqtSMCFsc2c3OwOdjRF42ht8ykzEcGnzrBKE54I04LkCtqcPt_2nlAcUavvjlwDm-y9RonrP97VwA0F9RCIZvFI1ypRY4EhAZM31qFUk8AxNOTqKcgSgSGhTDBBMi-AM5qA7nRoryH1nGKF9QsA",
#                     "width": 5312
#                 }
#             ],
#             "place_id": "ChIJ_f2KIK-VwoARI8VMS9Ibnko",
#             "reference": "CmRbAAAAPgvUCKY2yeT1Bv0DnDtPCIPAAPhyxjQfzpIWqX81ASq5iKzdQ9vHwg3YCYWia9Y3_du1iuGvxo-rGLQ32GXVYg5tuH57u1pqh57pFADiNeQLDyTZ0AmeafqAT6xlb_0lEhCeWq-t0NyRGN4_Xuy-FBz0GhTZKvFaHK1UZHbAEWtwNUmFJi1fyQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "2507 Airport, Burbank"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 34.2096399,
#                     "lng": -118.4896448
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 34.21039432989272,
#                         "lng": -118.4838608
#                     },
#                     "southwest": {
#                         "lat": 34.20769467010727,
#                         "lng": -118.4915728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png",
#             "id": "7008e7155542e7d08b9a3b10d9e6f6d4b0a53df8",
#             "name": "Van Nuys Airport",
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105356006364273310205/photos\">Yoram Algave</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA9XUN_gVJFS3XvfPPTKrOo-iJIuJafBkD0l_uTSD3eyL03P9XB7jMb-j5cXnPBeMi0xJCJeSPYzNw7g5JiQS-AsJYa7exBv_WLQur1UAWOz8ZVXBhZjLiqWbKKmwYjiIDEhCx6TZiNRqbESUsxvDeXcs7GhRygnI2tq6mQntWjT9Cam3HtqJEkg",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJt5Ms8kOXwoARKKwmIlNZLn4",
#             "rating": 4.5,
#             "reference": "CmRbAAAAIEqu07y87ZLJu16yajuBVe7PlQ7Qc1D_w8WArb1Bew2FM5GFdkRsqg-hiGIpXcWrl1NqjlDvxBOCBndGrQzuK8S-Yrlva2rcz45XesRwk5Nl9kpuzTC3mG_JRR4Qpp0_EhDMauKtDwFFfS_p7NVfohvWGhSz0KwIUUyQia1MiXmOsR19Vj-4hQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "16461 Sherman Way, Van Nuys"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 33.7942565,
#                     "lng": -118.0674125
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.79560537989273,
#                         "lng": -118.0660818201073
#                     },
#                     "southwest": {
#                         "lat": 33.79290572010729,
#                         "lng": -118.0687814798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png",
#             "id": "b167471644c31282bbba1fe5f3036867f5594acf",
#             "name": "San diego international airport",
#             "place_id": "ChIJtfCvO1gu3YARzG0mrqo6Cck",
#             "rating": 5,
#             "reference": "CmRbAAAAsBZb69MXcVDTpmvvT890qwuklW0hf3NBQ_dbjx6xYg_EpDTxweH0nSTqxF9L-LLW20DeS0H7Lhf4H_sLtZAlwPLZ1ZK1BpmYcVlh3U44OiqVjmX32FUVebga5HJ9ZlI5EhBHE15t3J6tpthw72eIU8YjGhQaprWMqFEJ9I1MVey4P9hlcOWnwg",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "2020 Constitution Ave, Los Alamitos"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 34.1983122,
#                     "lng": -118.3574036
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 34.20257795000001,
#                         "lng": -118.3448936
#                     },
#                     "southwest": {
#                         "lat": 34.18994894999999,
#                         "lng": -118.3615736
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png",
#             "id": "b4b5949fbb9292bcc8ea6cb46fc50bd8db34d0ce",
#             "name": "Bob Hope Airport",
#             "photos": [
#                 {
#                     "height": 2988,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102055379888537794634/photos\">Mark Kemper</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAYB4M8fPNPGZBrx-UknvhBCPF7DroJzJFs0BA-nTBPaK0hqr7pb7PpzXIlLf6av-Bjb6WjTEjeEuFqFicVKkpuP-HzMjhbQhMti1pvfp9_ic86HCF0o7ShfaGCCZ9EW8gEhBI3qBqQhK1GiZ3dG-A50jQGhTJuIt-4Smm_ol55U3TrFE0WKwKBg",
#                     "width": 5312
#                 }
#             ],
#             "place_id": "ChIJeUPPOU2UwoAR8QXY8RsY4W0",
#             "rating": 4.4,
#             "reference": "CmRbAAAAA1M4eFMwSmOfuH02vTfWOiOgCzbUotTYKDZ0aw5tuRGcj7URq59ZxeVKSMN8zRhL1nxTwOiEf0daqiOel3m66JpElbvK2IocJnDz9YcRrV0UQVgxdcZXY8-LelsXOfjsEhBH9DcKCTTkOcyUpGlvlyciGhSZRH1CfqljMqAiY7VWvaMrjrZIgA",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "2627 N Hollywood Way, Burbank"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 33.6761901,
#                     "lng": -117.8674759
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.6940212,
#                         "lng": -117.8528889000001
#                     },
#                     "southwest": {
#                         "lat": 33.6638888,
#                         "lng": -117.8730493
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png",
#             "id": "da9ed12835b3a597d4bcbc961a779ab353b0d145",
#             "name": "John Wayne Airport",
#             "opening_hours": {
#                 "open_now": false,
#                 "weekday_text": []
#             },
#             "photos": [
#                 {
#                     "height": 2618,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111653956642586952255/photos\">Justin Liao</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAZ4MUd72c6zdAZNzdPJlQr7E6LIdMD6u-4ZUggq1yFNdBwSbnlfDyI1FY8sNIn5QZm_9Kyjk7Gc9kB4pzZ-FW4N5ZwpzRKYEATd2MHMdtwTreZowT7myvlFWVHeSnMylTEhC8eoJXAc8D7leBd1yXTVHJGhSdn83VkZ3kPEJ-C34TNv_2dFREdw",
#                     "width": 3668
#                 }
#             ],
#             "place_id": "ChIJ70Cry-3e3IAR4hkRw_XoQck",
#             "rating": 4.4,
#             "reference": "CmRbAAAAn4VUrgv3T6Isrx7obQQ12SOnGyqDy0qEjsTldlElFdSkpvwkauj9gmeNFs9psBE4-mXh88HGSNk0dicA9XB1AwMm52EMPKUEfTFk37a2kz7q7IJ5LNo77o-FOjph-4YmEhD0BYT8P8q3thj9iIX5UakbGhSAByYpj7MBzf6RMaVXJO1iV-FfIA",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "18601 Airport Way, Santa Ana"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 33.8167909,
#                     "lng": -118.1513588
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.8198821,
#                         "lng": -118.1335313
#                     },
#                     "southwest": {
#                         "lat": 33.81576049999999,
#                         "lng": -118.1573013
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png",
#             "id": "442a1ec5af8174bba26a58ea09c646fb0c6bc1f2",
#             "name": "Long Beach Airport",
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/118264622088964989574/photos\">Robert Alvarez</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAqg2CaDttaCYhEXTzE1lD1Sf-g_UvfyNe_-quLJ5YsWOa6DaISwLGv_bBv-a3GxrXZn6jo7ml8jamxHHv6ZOYOjZJkF581aEK9kFrflSc_Ce5Bl0SRttWdRfy5WM6rQAtEhDHipYIwjEhey74BZshV8I3GhTPB1bqGnNm6YrwdvSsdoed-qi2IA",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJhQxDwTYy3YAR_ydWCFAr1wM",
#             "rating": 4.4,
#             "reference": "CmRbAAAA8KLOIidJAal3BLdunReSV3-QHrFy95jPkq18PB0soRm-p-YaeOk97-d3ff36edJBtA4uaLHDP_LVfqveG-LZv-EAMnN28ASP1g2Agouqsr6bCHLhONi2u92QqSXgyZKMEhA_rfJOv71P5q-2d5SUHin8GhR_Owm7x6qnxV8-dDqANY8gKTXNdA",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "4100 Donald Douglas Dr, Long Beach"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 33.9318983,
#                     "lng": -118.4151406
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.93324812989272,
#                         "lng": -118.4137907701073
#                     },
#                     "southwest": {
#                         "lat": 33.93054847010728,
#                         "lng": -118.4164904298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png",
#             "id": "b2a96303d7c7c9c98488c2fdd4edc6bfa79882a4",
#             "name": "Swissport",
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103378029318798277855/photos\">Robert Shumway</a>"
#                     ],
#                     "photo_reference": "CmRaAAAARHAd34m66JmoF5GtQcLtyCcf1w9bEtL8W_T-ZAd8vOvCQB9SMqJOQIwI4y1D8PzNDx21_kJVXUjnOvpnni7kduyFzhHulxmkrPkC4-7F5oqs9E_0jr807-XM_db0cRBJEhCh0WJhpONxBxDuSHIyUvxTGhSW_1XdVet6U1FqiIQkJepuiPvmDg",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJBb5LQT2xwoARSrZdVPFePXM",
#             "rating": 4,
#             "reference": "CmRbAAAAjoRj3No2UxdtxquGNnE1PIXnYiXk5iROcu_4le0HApuFTZlHuL_Jt0j0T5hXzIZSKbmh18rpzpq_r12vi7Bv2kAGepqZQYmt9se8IdyZQUOde8TPJAfzqhohHy1w9qbwEhDF9SHMk42WtdnQUM37lcKrGhTrXo7JMI1snfpPu-DcoSGtmeXDzg",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "7075 W Imperial Hwy, Los Angeles"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 33.7911583,
#                     "lng": -117.8345841
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.79265602989272,
#                         "lng": -117.8332223701073
#                     },
#                     "southwest": {
#                         "lat": 33.78995637010728,
#                         "lng": -117.8359220298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "id": "127de0f253dac7517780afb657b8b87a7fac390e",
#             "name": "RapidShuttle - John Wayne Airport",
#             "opening_hours": {
#                 "open_now": true,
#                 "weekday_text": []
#             },
#             "place_id": "ChIJj-EgqfnZ3IARbqS3OdykCYs",
#             "reference": "CmRbAAAAOq9EUERQbn1vfVaSWgNiNMka5jzoRY45YLvNAedoJTS2OOSHZqXqmQxDaGnm-lqOSOrjKfrCryR6fNGEsbwEKZj3YmwX2AOQvE6gOUUxM-M5aH7oa3hZY3gG9jcpFa5GEhBVf2MyAnX1A0Kuk_2PA6YYGhR919tXdHHiK3LHSkDJv9M6-SJ_5g",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "car_rental",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "290 N Oak St, Orange"
#         }
#     ],
#     "status": "OK"
# }
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.9741625,
#                     "lng": -87.9073214
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.9841819,
#                         "lng": -87.86557924999998
#                     },
#                     "southwest": {
#                         "lat": 41.97082269999999,
#                         "lng": -87.92123545
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png",
#             "id": "db999cdcbd87af444266b30568e04284e640d87f",
#             "name": "O'Hare International Airport",
#             "photos": [
#                 {
#                     "height": 1152,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101560702490921272606/photos\">O&#39;Hare International Airport</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA5Ahu_2J6CJBbvCcc7X8Xy7RD4unDo9O-UWBkWsCtq78bMGB6-C13cuQ7EsI5olqwZZDbq4jUbB44exj-NP1wDIWUQtKMVSdp-sAmuv6INn5MhbcFjB4U9i1myB3YWHesEhAAyGLVeCi2X8IvtuhTl-1_GhST1oEvntXCHZkwh8n4yxI7dCtXTA",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJ82J3aie0D4gRS61ZAgdHF1E",
#             "rating": 3.6,
#             "reference": "CmRbAAAAjPy7oVeR6BAvJrkFonTtI4jZhFk66FrOo91uGocr0firqSzPgA0OucafCWu56DcqkRuMQUsiizydpiKbTA3zwBvEgbkHo4sfV348hf2zDr56fFp8u6UYPxTYPplwE3IuEhA9JMGPvleQ1fVJc1OCJto8GhRSu6_prx0oCINqnmq9Gg0gb-2PoA",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "10000 W O'Hare Ave, Chicago"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.78677589999999,
#                     "lng": -87.7521884
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.79353715,
#                         "lng": -87.7309688
#                     },
#                     "southwest": {
#                         "lat": 41.78189015,
#                         "lng": -87.75926159999999
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png",
#             "id": "d32c3ea4dec6a4578cbb5b5c0c6557112ed55fe6",
#             "name": "Chicago Midway International Airport",
#             "photos": [
#                 {
#                     "height": 2988,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101706410116129287086/photos\">Sherrine Thompson</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA_lj-3nMMpILBX5nNYa9h8Y5I0NRS-Lf4u90BLpS6PTs1awqVtCb-QN9Mh0LtOS4-235p4MrZMMBYw0wWPVDXB9T81ORci5tKQgoRR1I0yRG1vFDLinf88CYDeZm6-nkNEhA3mtAGkkc0dPe0IAflFBTCGhTeGE--TANJalCk4MoXI3UFiafRlw",
#                     "width": 5312
#                 }
#             ],
#             "place_id": "ChIJhUOqAQYxDogRpVApj9dgipY",
#             "rating": 3.7,
#             "reference": "CmRbAAAA-kcthBFAKNlNqLsR3cBb9B_upmqg_7ozUN_VfTz4LvurEbUPkaZ-mCT3KU6-eqBDYyrr0szaslXQw3yFKt2Tmfrbm5Z3YleIQZyS-eYdWGKdo8250UVGWyk9oKbQ7lZBEhCH8V9Qqiq15EGZCvhYaY_QGhQYoj0K-LVwFE_VY95h2U2SALgGtA",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "5700 S Cicero Ave, Chicago"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.6177844,
#                     "lng": -87.4083934
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.61943812989273,
#                         "lng": -87.40716337010727
#                     },
#                     "southwest": {
#                         "lat": 41.61673847010728,
#                         "lng": -87.4098630298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png",
#             "id": "5b833f9d67acfa05ac9993be19f96eeaabf1b1a3",
#             "name": "Gary/Chicago International Airport",
#             "photos": [
#                 {
#                     "height": 3265,
#                     "html_attributions": [
# ...
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 34.0093083,
#                     "lng": -117.3042349
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 34.01080767989272,
#                         "lng": -117.3029768701073
#                     },
#                     "southwest": {
#                         "lat": 34.00810802010728,
#                         "lng": -117.3056765298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png",
#             "id": "21094fc464fc7e70325c6b8980e3985d9d71a688",
#             "name": "Ontarion International Airport",
#             "place_id": "ChIJAQA8ooKu3IARdohlrmTjtXs",
#             "reference": "CmRbAAAARlpJabpDOplqpJtgVN5hufS_BELhJMH7OX8GEF0r4TalfaUyn5gUziGEt6TyTtr9mVgD4X0gSFrC2jksUh8zpQyf2lo-TlhxfUAa1e2T3KQATDfnU7Fg66grKSDpch7KEhA4nFboupsmEyBFmuEmZfhcGhQalf-xlYBUvm8Ktr4ajQ-I6gcMSg",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "20561 Crooked Branch St, Riverside"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 33.7530113,
#                     "lng": -116.9899617
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.75436112989271,
#                         "lng": -116.9886118701073
#                     },
#                     "southwest": {
#                         "lat": 33.75166147010727,
#                         "lng": -116.9913115298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png",
#             "id": "4e26e339bfa6d47d6c752442ae38271738f2b114",
#             "name": "Ontario Airport",
#             "place_id": "ChIJJb6lthtl24ARlpQehC0JIE8",
#             "reference": "CmRbAAAAqu8AtaNF5zBC-oQzJrjYjPuAq2Neho7fkKtZnIYV6Dc-YXG3BD-W_PF8nf3iroFRoAI6qYCjsGmeSfGe27ppSTpnZVL3got7I44QR-zunpGC1U34HfaO4xaTSv6cq6rFEhAndVA5aMjOhwC5WuDYTCvtGhRi2cYn_6uMFX893rnPhiT68uWNtw",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Hemet"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 33.8700525,
#                     "lng": -117.2440739
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.87140007989272,
#                         "lng": -117.2425332701073
#                     },
#                     "southwest": {
#                         "lat": 33.86870042010728,
#                         "lng": -117.2452329298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png",
#             "id": "cb750759c221f7f68c057512a1f6cf19e9ecff67",
#             "name": "Millionair",
#             "opening_hours": {
#                 "open_now": false,
#                 "weekday_text": []
#             },
#             "photos": [
#                 {
#                     "height": 2268,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100236305649144282200/photos\">Juan Cedillo</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA3EMR_zSn79tdFqcZ3YT6_eb6cGG3MnRbTRjaPt0ID1hjpJuTOeXi0kKEeYjrCLDdScpRQ97-aEb9iLZ7rVfRjB3YssObRjlTcBBvesddkQkLw8fv-PVnZJxaW9slYB8HEhAry-t9yKg81jAnUVoMKQJoGhTZzcjvpm47j65lnpYCbO7FTJ6HdQ",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJJ4QH5bem3IAR7YlfcJ-h57Q",
#             "rating": 3.7,
#             "reference": "CmRbAAAAucHHrhHIEbBSs96EFvG9M8I4zFCRCl7XIaXXqWAv-sLwLV2F27BVi7VLUnQapRTAtRyjwqKH3nvQMgloWBTq2ZL2VG5AYcVfR3v-9eUmUAoS01XGzFLaxMa8IsVa89yAEhDLYpppvdMtFToN3PmfsueTGhT8PXyZakti3u8AtTEhylA_Akdp3Q",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "17405 Heacock St, Moreno Valley"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 34.1044926,
#                     "lng": -117.2465012
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 34.10581972989272,
#                         "lng": -117.2456713201073
#                     },
#                     "southwest": {
#                         "lat": 34.10312007010727,
#                         "lng": -117.2483709798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png",
#             "id": "5df06e9e6c4e1e3d661de000b678758c9a7fac1b",
#             "name": "Luxivair SBD",
#             "opening_hours": {
#                 "open_now": true,
#                 "weekday_text": []
#             },
#             "photos": [
#                 {
#                     "height": 1609,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111707378690515320042/photos\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAFWNZ2rWkOmphYW9jdMgfbwEvAQCS9f9IneAjju6yJlEuzQSc5O5peV9mwqHIYyK1idz0Zu-mdaM463Kh9qb2U-bn9di4WaU3spRTiqLERxSlnMM-QHYtuEaDLAKBV33ZEhB8aTJoBFYdzaKq0B5nNhORGhTz0qYkCcxno4QM7fpMFq1ForXt6A",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJTwfB0Eur3IARrFpulbyNbQI",
#             "rating": 4.9,
#             "reference": "CmRbAAAAjhgVJ7lsliCE_pUoSC88nenneZ8nIIv1GoT7f6OlJbbS6OMkyvQYGzuT3yJiefAPwUD-UOEP18D-_5OnPgAeXRpCSimg6GJpzSfGLdzvu3AMMkUrqoMuTGxYeqw-4vspEhBk8ce5tUAeSwYYKxijSMIGGhQMHiufcI1LjujqY6b3co-3TUpFEg",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "295 N Leland Norton Way, San Bernardino"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 33.9751601,
#                     "lng": -117.6352509
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.98684539999999,
#                         "lng": -117.63330195
#                     },
#                     "southwest": {
#                         "lat": 33.971265,
#                         "lng": -117.64109775
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png",
#             "id": "f2564af50d49d95c5e0c154f5a52ea2a661c7f54",
#             "name": "Chino Airport",
#             "photos": [
#                 {
#                     "height": 2448,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107368504585526649909/photos\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAJczYAX_0iyGEid4ZJmks2pGNzH1kI1dyO8edhGBbeDwuBCyIBRAi_pCGFmeMGXXK9Fjpk1N9vylbqN7C2KyeVvM3brGrDMAIikNA1qj5bGQ7gcUY6nB1nDSTKeCk2UHzEhBG73bwHhSZsTWDwteicOHEGhTsPNcgOrzGXLedYJjywctFwetNRw",
#                     "width": 3264
#                 }
#             ],
#             "place_id": "ChIJxc3wennL3IARB9cmwK04-pw",
#             "rating": 4.6,
#             "reference": "CmRbAAAAPYmxTwq0FLmSIh7OAQI9HKjXVAYnki2SszYilVHcO9_aKKOkMD_sUk_y3aBwxfs0RUuPQle4D4_Xuz2Nc8W_YhJJdsup6nroKWmT6q-x3hxBn6ZAxhk9GjS4eCuu_GY3EhCVCfhuYqpIq0VDRDsf2MquGhRoK9UZdefcH0FwGjqpWJQTm8XgnA",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "7000 Merrill Ave, Chino"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 34.103924,
#                     "lng": -117.2466766
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 34.10480212989272,
#                         "lng": -117.2457419701073
#                     },
#                     "southwest": {
#                         "lat": 34.10210247010728,
#                         "lng": -117.2484416298928
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png",
#             "id": "e12b9e68efef3107aa6705115ab83dfac1092fd9",
#             "name": "Million Air San Bernardino",
#             "place_id": "ChIJcTrBNTWr3IARAsmvbziMXhg",
#             "reference": "CmRbAAAAJRN6fs9UyxjqaUEWaMLRx3n6VlkQOrxlgJc0oFmcWLkWjoGEXu5PizW2KWpaOLWXjas5gIL_zSpGYzDBl08VYF22KvBq18E-puzj7iQ2nzB-eb_khRQVTrnNEIaqRp8IEhAGVUIxVumuctEnBfTO_z9OGhTqoWaKrf8pyV9XSsyUatIyqVqcIw",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "255 S Leland Norton Way, San Bernardino"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 34.1045589,
#                     "lng": -117.2499581
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 34.10594022989272,
#                         "lng": -117.2486080201073
#                     },
#                     "southwest": {
#                         "lat": 34.10324057010727,
#                         "lng": -117.2513076798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png",
#             "id": "ab6da422a80d03d23085c7409395e0c0d505e968",
#             "name": "Amazon Off-site Parking lot",
#             "place_id": "ChIJQSDeV0ur3IARTQwHQAjeWho",
#             "reference": "CmRbAAAAjfQ-Szy-W1McOTGww2oEMJuLGeKn6uoxvVypsQQOiyvRZbZloGt8Iiru-C16QmfiFznFjyRJnzINA56uxx5IV2zGL4Y5vzjx1OhHpYODCA27q2PqU24IdpqYK9Mm9sYOEhA7uK_oR5MFzBQS-ApA85vzGhSnenCU4Pl6oyCELvSMTY6qnfpukQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "1651 3rd St, San Bernardino"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 34.0972398,
#                     "lng": -117.2427853
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 34.09858962989273,
#                         "lng": -117.2414354701073
#                     },
#                     "southwest": {
#                         "lat": 34.09588997010728,
#                         "lng": -117.2441351298928
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png",
#             "id": "f1101045ec686dd55d45f56a224e7b205546dad5",
#             "name": "KSBD Tower 119.45",
#             "place_id": "ChIJZ_lz7Ter3IARkjWcCjgQrO8",
#             "rating": 4,
#             "reference": "CmRbAAAAJl7gVE6X_3yLsnVD3qBerBwxmDhBkcQXuncLbWKqaCT6MDvRRGUftyOZQoBmznRvq5oCT9F6C6lnD2uJ9EFuimyVy2bVmnUwPyi-1PE-HPKUjdtMHWtnPWOgmn_732EJEhAlcLTntLjB8gmQwDDDUJ23GhSUx5HOfSonEcs8YLMGa0c6xmC9uw",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "San Bernardino"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 33.7911583,
#                     "lng": -117.8345841
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.79265602989272,
#                         "lng": -117.8332223701073
#                     },
#                     "southwest": {
#                         "lat": 33.78995637010728,
#                         "lng": -117.8359220298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "id": "127de0f253dac7517780afb657b8b87a7fac390e",
#             "name": "RapidShuttle - John Wayne Airport",
#             "opening_hours": {
#                 "open_now": true,
#                 "weekday_text": []
#             },
#             "place_id": "ChIJj-EgqfnZ3IARbqS3OdykCYs",
#             "reference": "CmRbAAAAqZxjNo9qpihVI8MYPFxCOi71Ph3KGMluL6OPe_HgXjY7bIcuogfoTvNDolKoKVvNQGWKM0ZXCuwovgSs3zbs5muzkA4o6N3dmBdALR4O3EqcEwJKtb1eDyY-vaXXld8oEhCVRMUdC1LsZaa0mAL1XOl7GhTB7b_RLhHT3q3v7llSzg5XVpv-ng",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "car_rental",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "290 N Oak St, Orange"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 34.103345,
#                     "lng": -117.2719863
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 34.10469482989272,
#                         "lng": -117.2706364701073
#                     },
#                     "southwest": {
#                         "lat": 34.10199517010728,
#                         "lng": -117.2733361298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/airport-71.png",
#             "id": "39781b5519c983164977eddd426e6eb145c3c572",
#             "name": "County Heliport",
#             "place_id": "ChIJnQcPQlRTw4ARxlqrCjWmvAc",
#             "reference": "CmRbAAAA4xkwI-aFrqXiFtKJH8A2r8GrYx5zUgndrbn0gGBZpskR2pYjlMg2idZp1Eyf0qILcoHfsLh5blBcg610mx1GhDVYrchlwNM1fyN-Lgl7mOSh4cE_3hlqRTR8qlmAOz_VEhDtoVkqQiaQAdMh0HuHGl1XGhT-zDp7UFBjSFJJVrmh4trRp6SyIA",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "San Bernardino"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 33.6919104,
#                     "lng": -117.7743755
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.69320007989272,
#                         "lng": -117.7730843701073
#                     },
#                     "southwest": {
#                         "lat": 33.69050042010728,
#                         "lng": -117.7757840298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "id": "63d907f5c156ad7470eddeeb51b0acce622dc7ae",
#             "name": "AM PM Shuttle Service",
#             "opening_hours": {
#                 "open_now": true,
#                 "weekday_text": []
#             },
#             "place_id": "ChIJC522EP3c3IARwFJK6YGfw7g",
#             "rating": 3,
#             "reference": "CmRbAAAAsTXYKu9rwuMpFaDRWuSAQrmDyth1yEYPfm-BF3XNTdnjBcSsm_0OcTuKCAiTztiiopV_zAagw10JVFN1BONQ9d4_Vz1jtGJz6K0QDnu22SZv16E-t241ruCSfVNHXgJBEhBfg__s4xDXDAbPiAySuqCXGhSu7AwdsX0R0JHjQ8BNM7a3xWx9GQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "airport",
#                 "premise",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "53 Elksford Ave, Irvine"
#         }
#     ],
#     "status": "OK"
# }

# %%
# Save Data to csv
cities_pd.to_csv("Airport_Output.csv")

# Visualize to confirm airport data appears
cities_pd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-492b28f254e4> in <module>()
#       1 # Save Data to csv
# ----> 2 cities_pd.to_csv("Airport_Output.csv")
#       3
#       4 # Visualize to confirm airport data appears
#       5 cities_pd
#
# NameError: name 'cities_pd' is not defined

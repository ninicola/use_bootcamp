# %%
# Dependencies
import requests
import json

# Google developer API key
from config import gkey

# %%
# geocoordinates
target_coordinates = "43.6187102, -116.2146068"
target_search = "Chinese"
target_radius = 8000
target_type = "restaurant"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "keyword": target_search,
    "radius": target_radius,
    "type": target_type,
    "key": gkey
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)

# %%
# print the response url, avoid doing for public github repos in order to avoid exposing key
#print(response.url)

# %%
# convert response to json
places_data = response.json()
# Print the json (pretty printed)
print(json.dumps(places_data, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "CrQCLgEAAOruuIpviLLA3Dx3LxrwKNHMRaX0ZN65-jTFJwSuhnyAHIeNWCblWaXvf6QZ5H-FK2Brjays8BKOee0Yh-M70KWGJ6gBzIJNYbhh-l7cNOmQHb1Q-D2QJnK2Mayaoq-pn0kAADZduJ2OJJRX5zlYC30JIydKuGdMQx-GHQC9hFEd4CaBKMSxdwujm6me3hT_Cme8VRDNjk2moEKmu6Ihlt1JQgIAcSYKA2bl6usbH1cwGGd6d-7aUTXkCjUXFY4WFsFUvQ9wo8gEcNgLP8tdl0Vw6XXWGAH2BoR9uPuGqSZeHEenUpJncLvf3YJht_jwJLCN_u3lzq6MWCECExM660KdWmKbVTHjAx5EtR2jGrSxin_ttntUnxy1plZ9xMe9l5kfgpnC-LnqV78TvLQqa_oSEIFNhrQtUMJbTlLYSMFlm_IaFNbtKrqQDi2zJGkCpt_tYBfwFoBZ",
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.6201152,
#                     "lng": -116.312547
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.62114217989272,
#                         "lng": -116.3112022701073
#                     },
#                     "southwest": {
#                         "lat": 43.61844252010728,
#                         "lng": -116.3139019298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "4929e977dc1f7858efe1b37024d1fa6db3684772",
#             "name": "China Grand Buffet",
#             "opening_hours": {
#                 "open_now": true,
#                 "weekday_text": []
#             },
#             "photos": [
#                 {
#                     "height": 3120,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101287468922822261096/photos\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAzFz33ngZE5clwWrMPB_zqvbA3_ezcxHFBF5nj70OBO1xtpzEq9eQWQ7ctapqA85QF3JkKqAy98r-trN6-XNb_-p4F1v-B0pvXvZtufw-fHlc6pMGehFZaD-DBg2ygEc5EhAo9E2y6pIdC3Uremz_Gh7KGhTrVLmqOVAPDxdiqies2ACyKQAmzw",
#                     "width": 4160
#                 }
#             ],
#             "place_id": "ChIJTSFfGNRVrlQRuTYkj0zGqMM",
#             "price_level": 1,
#             "rating": 4.2,
#             "reference": "CmRbAAAAJ6X6KiRfHqVQP8H5Ngn8yzv-Gc2oMVdpulfJJx25KK3be5NyCPg7DsdVqeGlBq9GOHUAvGw4wdETh2NJbiEPN8Nc7oD4bzzRlFDJjnNAWKTTGUsJGYhDzReN9i9lKJbpEhBNeKBJCBdc01TieI98g1X-GhTEfZDBvcP_2ZFRfHmW8C3NwsAvwg",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "10498 W Fairview Ave, Boise"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.5904072,
#                     "lng": -116.2893377
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.59169252989272,
#                         "lng": -116.2879877701073
#                     },
#                     "southwest": {
#                         "lat": 43.58899287010728,
#                         "lng": -116.2906874298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "fd94ac3594bbff6c11b913eacb10273d996e48b0",
#             "name": "Lucky Palace Chinese Restaurant",
#             "opening_hours": {
#                 "open_now": true,
#                 "weekday_text": []
#             },
#             "photos": [
#                 {
#                     "height": 2952,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107131937753504663981/photos\">Carter Wigley</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAQdmpi2rMFZRzREo0-AzLY7H-kOsil8LzWXv7UrrL3YPi0798sQCH1FKNni4eQI7i1qLsVJMxllWmoB2KcCGFHsa2_TdBlSV7HtqtMjgRGB3AodKBZJERgP5lNmx3Vd1lEhBU5GtXyMWLo1asQNges27CGhTmdh0cS4D9FSfqGTpwzNqiD0G8Fw",
#                     "width": 5248
#                 }
#             ],
#             "place_id": "ChIJ5RKyTVZWrlQRY-t-LLVVQ9M",
#             "price_level": 2,
#             "rating": 3.6,
#             "reference": "CmRbAAAAkeiflQKNcpVOnzHH_GYKfqmGopkXORtdldMbFDmM6TZuVs7iCdEWusPzN8K9tYLyOhQM5NkByVFjyoM_LZiPxzBBvBR-tc65Z3iMTxxpr4KSnHu4qPh-huooI1UDO3ZMEhBI0O_08Lj2C2il5XM0N6mVGhQJaM9A6M2_CmUGQ6RINlzK6Zdk2A",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "1645, 8630 W Overland Rd, Boise"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.6180841,
#                     "lng": -116.2031626
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.61938607989273,
#                         "lng": -116.2017191701073
#                     },
#                     "southwest": {
#                         "lat": 43.61668642010729,
#                         "lng": -116.2044188298928
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "e525d78c947c5527fadf72ee54777d3a3517c3a1",
#             "name": "Yen Ching Restaurant",
#             "opening_hours": {
#                 "open_now": true,
#                 "weekday_text": []
#             },
#             "photos": [
#                 {
#                     "height": 3456,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111898372840758744049/photos\">Robert Stucker</a>"
#                     ],
#                     "photo_reference": "CmRaAAAADH7-Nsn635ONzSOlsjYEXrbgO2QVnRz92742hjG-L9Z6-i3ADqZWk-EJ2vJSXEkLSuuH7OiUbsZuLpz0I_hoEXGKSL2Xqq00Un8Ox2saxT7O8qY9GOY7cxZFRTfweSn0EhBHMkLIZgwff-dy3CfMmmjWGhQW7yMJF4sJ6Fbx611QE2BhsaJE-Q",
#                     "width": 4608
#                 }
#             ],
#             "place_id": "ChIJD1s29-P4rlQR0QVGxC9AWY0",
#             "price_level": 2,
#             "rating": 4.1,
#             "reference": "CmRbAAAA8YwiNoG1xJbw_jiV8Cz1d0qsZg_Y0EFGZdmjHw7cPLe_dSeZdnSwfBLm1j5_owpIm2tJAxQ3Artqyq6MURW2VHo-dcznnjDi-c_knoHqn-azZAtLCkRn6GwaU422O-6dEhD8wcshUv43gQ2I3ilRjEQ4GhQWJfm6zbmgp2p57ImYWiXeIQ7qjg",
#             "scope": "GOOGLE",
#             "types": [
#                 "bar",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "305 N 9th St, Boise"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.6251218,
#                     "lng": -116.2123933
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.62631952989272,
#                         "lng": -116.2111869701072
#                     },
#                     "southwest": {
#                         "lat": 43.62361987010728,
#                         "lng": -116.2138866298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "b1910608eed20a9557d6d9fb29675484932ad9ce",
#             "name": "North End Chinese Restaurant",
#             "opening_hours": {
#                 "open_now": true,
#                 "weekday_text": []
#             },
#             "photos": [
#                 {
#                     "height": 1080,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103039634556116345378/photos\">Duane Hughes</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAObUznI314tebruy0rwznIYA6cH4v5IcESQMnGDRAqI9ueb86LXt_Q8MbZXfDDelPm7gtt35OCOJALlUs5wAG0X27QStOq2GM_1LQX1CNsVM5Vkt3upLVdUVaCCO_VX2nEhC4IWywwXS8yIeZlyvBLhgkGhQetBADINbfHs8plVPyzYbXTrr7Vg",
#                     "width": 1920
#                 }
#             ],
#             "place_id": "ChIJP5lMQNz4rlQRPRigHmorMWw",
#             "rating": 3.9,
#             "reference": "CmRbAAAAu8JCD1j04p-ghMugl7Qv9vmQeRCDw4qy-saXUai9nTqLayu2MysnBEwavcuYt6AkABX5EaEAsiku5ys7Lf2uWysnBuJdQgUPBJG_hw-7Sj5h8ahXvl5yBveu9aV1ugfXEhAgKqAcM_pTp-HkBk4GsHEiGhTwbnd61w1kGoxY6isyCedL_7Yizw",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "3955, 1806 W State St, Boise"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.6189873,
#                     "lng": -116.2912796
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.62057422989272,
#                         "lng": -116.2899303701073
#                     },
#                     "southwest": {
#                         "lat": 43.61787457010728,
#                         "lng": -116.2926300298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "61f5604ae4b98f4178f367df4a80b246abebe85f",
#             "name": "Confucius Restaurant",
#             "opening_hours": {
#                 "open_now": true,
#                 "weekday_text": []
#             },
#             "photos": [
#                 {
#                     "height": 1960,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114834946914295989143/photos\">Michael Hirst</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAo7IHqjLRBLn7ZNIlST_1AJf4yTNK_ZZVBkA9W_IyA0UYwEYjUo2Mnr72Dwv8u01KG7nMnQ9enKl5bNHWSdAekhvUhtxDog9iy6UkMNgs7nkGvkdJ78PXyC_hCuUM-vISEhDGqbNueoGQztcyo_PXQfu4GhTBj3rdPNVqgVnIdqFoB9gyV8cskQ",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJxXnvGXVWrlQRdHTY4TuLvMo",
#             "price_level": 2,
#             "rating": 4.2,
#             "reference": "CmRbAAAAuYdcWq65qZgR3lZIFlnUHf5zbGsHPTfYCE9EkmFMkL93oGNH77hQRfsm1cufw6dU5wLsJqOjFiUrMiUeaRiY57aETV1LNA6dJNJuAOojfPJCjxaeHvhzuUqtLBRyN5hREhDik1lalxOuxBrgP8cpNPU6GhRKIw3_vizd4Vcd4eiVePFM4Z8t3A",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "8775 W Fairview Ave, Boise"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.5888893,
#                     "lng": -116.2776039
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.59087617989272,
#                         "lng": -116.2762246701073
#                     },
#                     "southwest": {
#                         "lat": 43.58817652010728,
#                         "lng": -116.2789243298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "286cea6abbf1b8ca63e5b1d4223cf74c9998e69e",
#             "name": "Guang Zhou Restaurant",
#             "opening_hours": {
#                 "open_now": true,
#                 "weekday_text": []
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114780042035600807806/photos\">Mikali Beaumont</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAF2MvbBYrzs0_KbEsta54BNhMl7J1m7hMk-hP9xCKCjQvDM1ay1udZuSjz_w8Nbll8veJr_YfSAi-uXgsNwfe-Npg5A7rsFW8q0lZUa0b_9xJP94xwmTsUcc2LFITZC5BEhBWotDL9_qZOhxOuPfPSAuyGhRFRMaKRGezjwsPIkI4oVTUwxg-Ow",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJDT-7DlJWrlQRO7rtBTzZf6s",
#             "price_level": 1,
#             "rating": 3.9,
#             "reference": "CmRbAAAABJAHOrmEpRzSpXjLCSHTE4py-Ass9olrL_PG9Pyl29Pz1mHarHsWM-UidDbdIaKBhEGR3mVwW8y9vBksW3HyiQarG2Wk9giZOnyFRC2mvmko3k4oO5KCmIwBl4pFGECAEhDsXzEuq7wQDA6lYpH7DqAgGhQMM2srnrGwEo2T6ngkbohJAA-35A",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "7609 W Overland Rd, Boise"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.5896223,
#                     "lng": -116.2166041
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.59108857989272,
#                         "lng": -116.2152532201073
#                     },
#                     "southwest": {
#                         "lat": 43.58838892010727,
#                         "lng": -116.2179528798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "a0200d75209b9aef071f6d00d0ad237131771f5c",
#             "name": "Panda Garden",
#             "opening_hours": {
#                 "open_now": true,
#                 "weekday_text": []
#             },
#             "photos": [
#                 {
#                     "height": 3000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116458307585709549387/photos\">Michael Whitehead</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAqW9jJBBKMdPn3fxnrvr_knydejIrDZpPQ_HzvE2kuIXhjTLlKktjalIO3QfL3dXkSBFHDBhz50olW_YXOnONBr_q7DZ6hkhZ_L3QH-KEkkehg0P0jSECX8PPKGNP9EH3EhDPBtJMUsx0zidowN5gZ9wyGhQeu69JqHyhWkA-V_KW7xgehWvRrQ",
#                     "width": 4000
#                 }
#             ],
#             "place_id": "ChIJ6W_ERHD4rlQRz7pUm4liz7Y",
#             "price_level": 2,
#             "rating": 3.5,
#             "reference": "CmRbAAAAd_DA_yYjxLG_QBzcpMue6blZlh5ZZG5WZOQxEn75OK1LVud9WGt8Zgx1aYLADM2wgtNx6_I6bhF66V-yE3GDJ2ilzv4XsbkNTzLZZeHMeAgX4pJGn_Zp-TTNGMvNmXAlEhDlw8Ftb6Ty6uowt-fuXFe6GhTs-oINAxKO9h2HOeiYgcLFIX2-Qw",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "2801 W Overland Rd, Boise"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.6137078,
#                     "lng": -116.2058037
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.61498032989272,
#                         "lng": -116.2043024701073
#                     },
#                     "southwest": {
#                         "lat": 43.61228067010727,
#                         "lng": -116.2070021298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "b718466fdc95f8586e92b72cac5f0632bf5a24a4",
#             "name": "P.F. Chang's",
#             "opening_hours": {
#                 "open_now": true,
#                 "weekday_text": []
#             },
#             "photos": [
#                 {
#                     "height": 3072,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113205105119011446064/photos\">Zaiga Morris</a>"
#                     ],
#                     "photo_reference": "CmRaAAAACL3zNYsZf4AROvwqtw8o_albimTCNHqxVQsjfnGAN26OxTNrOz55nLuBciiuUniBRA5FS85FbEk_YogKbQQRshK-GCRwv-aZ_OlBnNJGGJfOawrtOw62i8xrbKt5SljjEhBWw51E5mfYNyaWtEMPsanZGhTAYEbCyj5d7py8udWXO4uW2CJLcg",
#                     "width": 4096
#                 }
#             ],
#             "place_id": "ChIJEVx3TeX4rlQR4QkPYThohEg",
#             "price_level": 2,
#             "rating": 4,
#             "reference": "CmRbAAAAl12zJJydOTkRjGy6XLy8KTviOggU4uZv1UOduM4CRVDZzI6LkGn6wHIKsjxXQh2POAmxDpOUO1GhPII3Ku-_EPzuFPea5-maYrcYa8NH9VZUa5_HLs-YXXowGKD_nKaXEhC4pRuFbRt-MKN07Cv_u_DBGhTIer7ByW3DzUzHfqilQSsojlFI3w",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "391 S 8th St, Boise"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.6148417,
#                     "lng": -116.2427971
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.61619362989272,
#                         "lng": -116.2417700701073
#                     },
#                     "southwest": {
#                         "lat": 43.61349397010728,
#                         "lng": -116.2444697298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "1cf6836746006f010fa362260831d258ddc3d8b7",
#             "name": "Golden Star Restaurant",
#             "opening_hours": {
#                 "open_now": true,
#                 "weekday_text": []
#             },
#             "photos": [
#                 {
#                     "height": 1080,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101772808443136062273/photos\">Daniel Fredrickson</a>"
#                     ],
#                     "photo_reference": "CmRaAAAATsOKeMI-A99SsDrkEb3ncEMX2LLTd9arNlt76kruuptb5OqNOKAMST9qxH0lGTDiTtxD5O0TgG3vVqYMwh6x8iPZBvh0Yus_5SOp2c6q0HEmI9ltnfzjsb1zaWbZvRqMEhC-QrhD6HGABftCTUY_nBvhGhQE8SbZg0-eJD2NsYAsoEI0h3AtqA",
#                     "width": 1920
#                 }
#             ],
#             "place_id": "ChIJTctsXaL4rlQRbC1U996y4-0",
#             "price_level": 2,
#             "rating": 4.3,
#             "reference": "CmRbAAAAI4J6FL1MjE1rPK_n92MNMInECboHhZ9x--oXLmEJ9RMBjsPF8EEeFbUo42yNF5ftyjNnrnoUY35fBOaQVvn4r-Mqze_EZskbUdf8xL3lrXK266qMk8MANlNdtQQNUmtNEhDSEzfltMzGesUXsv6LXMbaGhShhaQR73jsEVEPXBdZEWHe420TQg",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "1142 N Orchard St, Boise"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.5915577,
#                     "lng": -116.3116912
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.59226937989272,
#                         "lng": -116.3103367201073
#                     },
#                     "southwest": {
#                         "lat": 43.58956972010727,
#                         "lng": -116.3130363798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "f2b62644707695960bbe5842c39bf0941643231f",
#             "name": "Great Wall Restaurant",
#             "opening_hours": {
#                 "open_now": true,
#                 "weekday_text": []
#             },
#             "photos": [
#                 {
#                     "height": 3464,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106248445007066630052/photos\">Waylon Pearson</a>"
#                     ],
#                     "photo_reference": "CmRZAAAAnvDzHySuwJldcbH3eMhf1tgTC4SB6toUXadI6hGHMnssFOBBCkTBRPOSwCXaZE2By1l7JpwYsx_qiWSnQ6GXy1Di68WwS5UoioTnkKLizrh0Ob5YzkC2FM7ZQhRngOrwEhAMwwxSpg2256A_lQIzEogdGhRkwLvGxmw5gYGtz98kg8yfzdMaow",
#                     "width": 4618
#                 }
#             ],
#             "place_id": "ChIJle9LyO5WrlQRyBqJqPmCLQI",
#             "price_level": 2,
#             "rating": 3.4,
#             "reference": "CmRbAAAAW6xYKBLEOAoIE_cJkrmVVL5kKpjWnc7G2QvWtH8jcrTY96jDlcPcLVZNRHTEHfPnblLcVTfB3MArBid29esQiy7wIQlVqb33qyptPqlOYp2qcv93gErZ2LS1WwvCLPfnEhCwLVJNl9Wgj1_yv7aynxOyGhS_VtUq9ZR40or960xB6A35RHtUbw",
#             "scope": "GOOGLE",
#             "types": [
#                 "meal_delivery",
#                 "meal_takeaway",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "10398 W Overland Rd, Boise"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.590018,
#                     "lng": -116.2418638
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.59124047989273,
#                         "lng": -116.2405127701073
#                     },
#                     "southwest": {
#                         "lat": 43.58854082010728,
#                         "lng": -116.2432124298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "2a3be484e3d636b3b1bb36a2cdb40d25e7768fe5",
#             "name": "Quik-Wok Restaurant",
#             "opening_hours": {
#                 "open_now": true,
#                 "weekday_text": []
#             },
#             "photos": [
#                 {
#                     "height": 1080,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112414804993438343758/photos\">Thierry Oberosler</a>"
#                     ],
#                     "photo_reference": "CmRaAAAARw97UBRkpzE1S9h8C9sNHQdFumNRxhta2-o_tCkmzmnuU_uwwetfgnLhoPe08kSHbHfSLw7Jb1jbjrVu4LGChnBFga5skBADg2ThBorczg4FbozH73N-Cj-3eurbaOCpEhDMRjKmEsuSDOo5XGfmKtqYGhTbRz7lt1OobrvKv-xQrL2b8ApchQ",
#                     "width": 1920
#                 }
#             ],
#             "place_id": "ChIJbRshL9JXrlQRDa61aB-RK2E",
#             "price_level": 1,
#             "rating": 3,
#             "reference": "CmRbAAAAlafyeAaWhmhz0ghhrLbtkuhegswCC9O8SGrDXelKp7mhb-ieoP_nvr83RtVBeVRjlR9vIXZdR0f3eriP5s3whJW3WKbyQDVY7j2lnWtqXlrOWEK9LUXpnYNgTqkiUG8gEhCyda5G4TiQozafzDiAPRIYGhTF3SqNnUyC5bgnqzRxVEkecPbyzA",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "4858 W Overland Rd, Boise"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.6283042,
#                     "lng": -116.2467568
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.62956617989272,
#                         "lng": -116.2455265701073
#                     },
#                     "southwest": {
#                         "lat": 43.62686652010727,
#                         "lng": -116.2482262298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "0b0f80cee20a9828830a5d2afc4b35e9cae20d53",
#             "name": "Golden Wok",
#             "opening_hours": {
#                 "open_now": true,
#                 "weekday_text": []
#             },
#             "photos": [
#                 {
#                     "height": 4032,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108564864349711743478/photos\">Trang Pham</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAflrb4aBSmsmc2fkXTCGqSUgOPWQnCn_2PY773ncZKGpur51FHYTp3oN62p1jArnxwY9D5wfrblzoexI4eHJsik-zpedtLnM6gBnMTIk2i7qYLvC9h7HwZSBvlgYQdvAJEhC4hU8c6PmIm6mDzPy64pjnGhSgWZx1gVt2kSZbolitEkFjEKCP4g",
#                     "width": 3024
#                 }
#             ],
#             "place_id": "ChIJ4-wGxrP4rlQRQBpLRX5r_t0",
#             "price_level": 2,
#             "rating": 3.9,
#             "reference": "CmRbAAAAq2ase4yCLhpbZerc0xPIDA6rQ2MRvJzKN3iulVx6dsmgs9G6RG-K4ibXvq2kj4zyCBoOtUwTyEgX272NJ0fe4vXkNGlyaeOBk6pgo-rtakaizXpqrbI_EEfSgcsmgUwhEhD92qgJEIZsfoQIbLKZ-w5yGhQqgJFwM0mn8M30FuIMdKUQE4GKQw",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "6412, 3948 W Chinden Blvd, Boise"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.577295,
#                     "lng": -116.195009
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.57866402989273,
#                         "lng": -116.1930016201073
#                     },
#                     "southwest": {
#                         "lat": 43.57596437010728,
#                         "lng": -116.1957012798928
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "f545045ba2cd56701c0a4aac1994c9814ae16ba4",
#             "name": "Season Wok",
#             "opening_hours": {
#                 "open_now": true,
#                 "weekday_text": []
#             },
#             "photos": [
#                 {
#                     "height": 2952,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104156735198363326200/photos\">David Ku</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAXtNX6dCB3un7JgjVkFaJeWve1ezWuE63bnBEvFO22tseTTjlfhfEZgkp0I7A7U8s6rBfzoMCyEJ-8IU9MB7QL_ADtsg4my7JJphSvkByk6GscXOBME_1B5OYR_HqfcKDEhD1KbkMitAHVcAGw5TJzrbFGhSnXsMZVVWzCqR9fxNSDA1oMrg2WA",
#                     "width": 5248
#                 }
#             ],
#             "place_id": "ChIJ_9TdpxD4rlQRdg8ROoJbNSw",
#             "rating": 3.4,
#             "reference": "CmRbAAAAGlqXqNv0P41_OoJYW35vQXr4WQPsP_flC0NyrIlQjcCne-G9zhUA7-3P0Z03L0w24aoBuFkgtkeOvoe-Gz6-UftuuJxzlhr3MJiTeW-_vS2DPFe0_TOazRI4CjMNgOR1EhDYnqDeNGje3ZAfTBlKUTSzGhQKQZHKQu_OY9gY-9A9Y09eUfSMlw",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "2775 S Broadway Ave, Boise"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.612365,
#                     "lng": -116.2430364
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.61334207989272,
#                         "lng": -116.2416909201073
#                     },
#                     "southwest": {
#                         "lat": 43.61064242010727,
#                         "lng": -116.2443905798928
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "4d5492174ac6d8559bec3d50ea75de99809e2400",
#             "name": "Wok-Inn Noodle",
#             "opening_hours": {
#                 "open_now": true,
#                 "weekday_text": []
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117660745759032282483/photos\">Sandra Capri</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAAOWT5xko1iSBdmKGtBRVOzVtPYq2ScbEMxSzMOmFXByjcdpL4NZB0qZn6b0ZI4ZdxrdYcRzd0SzE7gpaTJTw9OJXn2UWAEbLqPNjvDZJhaasBRKF2oN7rYPevkKGcAuTEhBMvQjPd0eFDq3H8BiAhwxSGhSryAxTCnBsfAkWXT9quE4y5TbqAw",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJe9STjx9WrlQRnMGkKZFN9V4",
#             "price_level": 1,
#             "rating": 4.3,
#             "reference": "CmRbAAAAPnaOgJLzsQgRdOFarfdSV77r7ONMH_ZAdeIb4gszZq60xycFtZ4V1Sg3HIIzfNOXusRwkEs4riJFjaCw0_kyXOTulfywLbLjM4Xe591IZ8D4Z0auxArWO8p0-KTLgxPTEhAiwf3divemt66HE7kt2SO6GhTKu677YValq9hw-idhlixl35puTA",
#             "scope": "GOOGLE",
#             "types": [
#                 "meal_takeaway",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "4912 Emerald St, Boise"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.6073482,
#                     "lng": -116.2787701
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.60869802989272,
#                         "lng": -116.2774202701073
#                     },
#                     "southwest": {
#                         "lat": 43.60599837010727,
#                         "lng": -116.2801199298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "2ed6cc10f5ade931ec1fecc1f07910be5091b074",
#             "name": "Panda Express",
#             "opening_hours": {
#                 "open_now": true,
#                 "weekday_text": []
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104961771114871630072/photos\">Bobbie Owen</a>"
#                     ],
#                     "photo_reference": "CmRaAAAATyXYA_zWfe7DuZwzTCAHfdb1_NiL9gPDlt6MaD5vWr_InhXaOjQKBjsd0hQdYJ13N9ffGX67GdjFv3FmeC9G-DhOnC4AFJ_tCoL_nNVLYpyg54x_Z2gZkrgxfpuGdkq0EhDrQwZ4KWUzsedMaCPPTeSvGhTQ9Nl04xlEhpHi3LsdHIr-swdgPg",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJfYBLkWpWrlQRjig0x7oVFfk",
#             "price_level": 1,
#             "rating": 2.9,
#             "reference": "CmRbAAAA4QUkQxUCa5cslZhcn3db_hfUEr7m-hSzo9NH96CVWnEsD2caEP4sZ40yvlpyFBS3hM-AklGaPGYG4MGiT3MJPcOy7jfdvtles5K_hO2QCr2Myg5Rkzry_T7-pEVHV5BDEhBGFHGOAGpJQ-p7NY9OFggVGhT2bTMmOSdeKCu5MnAidgVOo2pbBQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "350 N Milwaukee St, Boise"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.6128923,
#                     "lng": -116.2031389
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.61431167989272,
#                         "lng": -116.2017124701073
#                     },
#                     "southwest": {
#                         "lat": 43.61161202010728,
#                         "lng": -116.2044121298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "19d766843750bbddb9001eae857795d08938d66d",
#             "name": "Panda Express",
#             "opening_hours": {
#                 "open_now": true,
#                 "weekday_text": []
#             },
#             "photos": [
#                 {
#                     "height": 2340,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113887723557452427093/photos\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAACZTu148jr08gTZKoQ-4WjfQtyNYL4YopzKWk1t-PidFDQGHVdGkQPIYTpxuMBaZWR60a4pqiWO8ipVugYETfV3yvAQ44fOlzCCJOSHVSzlSGVE2T_teclcF86eJCggBEhCUxSiLLR50syKOQeR5LjW6GhQkfrmqlmQuRwYdq0VV44LbN6InrA",
#                     "width": 4160
#                 }
#             ],
#             "place_id": "ChIJkevL-_r4rlQRdCX2O8ZXDsM",
#             "price_level": 1,
#             "rating": 3.4,
#             "reference": "CmRbAAAA5bME5CFVuA7juXViHbZpZOYDQzJJbtxZv4ivGZiuyLXD6lofSKSJ2E_1WQ1gwCgG_ZFfpJerA5UZuLyW4uZhGFNpbblwqowNKSLJAHGD5X-0HLBXA-d2kegikKDNXT1jEhC-u84nqVDILG1tQoqxv83_GhSqShFsr9H7d5HDhr_pNMkqM0pWaA",
#             "scope": "GOOGLE",
#             "types": [
#                 "meal_takeaway",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "601 W Front St, Boise"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.5906287,
#                     "lng": -116.2801473
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.59183377989272,
#                         "lng": -116.2787997701073
#                     },
#                     "southwest": {
#                         "lat": 43.58913412010727,
#                         "lng": -116.2814994298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "ae08003ee569010604f4fa91f90e3d341be10ece",
#             "name": "Panda Express",
#             "opening_hours": {
#                 "open_now": true,
#                 "weekday_text": []
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104665938415869848703/photos\">Steven Sloan</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAueYwd4o50i9dHl4j7qguAFJ__6MokiJfkaPsujfC2X8cNUvPt4q60-pptQ0ar3lnnFdqqKCvviuYURL6q0ekTo17zFkCHe5g3tBxgbEBpPI1Dek4lWrCL2z_9YGjKQRaEhCcLCfm_dQApPBPSS07saL7GhSigq6qU2ZPaLu8OLAkwc75RdLGXg",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJb15nIlJWrlQRcvGGNq_0WC8",
#             "price_level": 1,
#             "rating": 4.1,
#             "reference": "CmRbAAAA1LM0LvQ3odIWgXr3ecJ78OA7De11ObZDxFI2Kn6ClxdHMJ2CB7aDA0ZZhUhhxPyyQh0bVSCP06ON2aw4OSeFml9foVube50RB-tH7veo-bq5Vge08RqGD1tsWGMUTBhmEhB7U1ftftes0zhwvlC_yVQbGhSsNJatEaUI96aqBOMsoBSZ6Zzzdw",
#             "scope": "GOOGLE",
#             "types": [
#                 "meal_takeaway",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "7804 W Overland Rd, Boise"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.618054,
#                     "lng": -116.282076
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.6200802,
#                         "lng": -116.2808748701073
#                     },
#                     "southwest": {
#                         "lat": 43.6173786,
#                         "lng": -116.2835745298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "f81ca5c2cbaac12e40248363e8e791490f61b119",
#             "name": "City Buffet",
#             "opening_hours": {
#                 "open_now": true,
#                 "weekday_text": []
#             },
#             "photos": [
#                 {
#                     "height": 2988,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103425469668596867526/photos\">dee shuck</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAmDHk4j7oQWgre_9SaZqUrsFTdmueXFCzwBWP-kp5wbec0T3ZdDLhkzaCYxGj8XvQJ6B5lJo0yqfG7GMhMYBFEulihnS6TpszFYQ0GER998v47qgGmRR9PzjJqPxrAmVAEhDUZCrZu50hXJzJIfpstNo-GhRBR06uCS9jXtBGDniv97o627f2wA",
#                     "width": 5312
#                 }
#             ],
#             "place_id": "ChIJDU3kvQtWrlQRqEpYSPtJ_5I",
#             "price_level": 2,
#             "rating": 4,
#             "reference": "CmRbAAAAxc8H0dnHSIDHQBwiFymT0aJoLm7083nOICtdTb2T4AuESOdSie9bnfkP6ypXq1XtgT30Lp62cxsZqHHxsPRwluQUldc6TqAnc0DMrhWb7GdG9LN7S6mC9jFLTSAZuAyOEhBukXqjcrgONH8AkEL8Ms19GhTJx6lokiEo8bf4yLmmE_ha5YM5vQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "8049 W Fairview Ave, Boise"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.6487815,
#                     "lng": -116.2461813
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.64982807989271,
#                         "lng": -116.2452581201073
#                     },
#                     "southwest": {
#                         "lat": 43.64712842010727,
#                         "lng": -116.2479577798928
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "1d24153141ea5604e7f247978036ec0b8f45d75b",
#             "name": "New Garden Chinese Restaurant",
#             "opening_hours": {
#                 "open_now": true,
#                 "weekday_text": []
#             },
#             "photos": [
#                 {
#                     "height": 1920,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107509501816582528738/photos\">Emily Siess Donnellan</a>"
#                     ],
#                     "photo_reference": "CmRaAAAADPEt6YolrHyJu82GLd5tLMcPHpebEls4HTrrTX8dgiDZ0e-tpi_Z8v1GhMoygO_Phre2qTdLh5pWwoz9sSdSaGPXnKr5id0HXDnAjB45vWdDCd0n2vU9H6xq7-Uh3AWvEhDUSSmGZ8slp-iSitswRqxcGhRYSsZbr5hA2iHB3WBkRZ_s-X5bZg",
#                     "width": 1080
#                 }
#             ],
#             "place_id": "ChIJvwYXUDz_rlQRKpVyY618JMM",
#             "rating": 4.1,
#             "reference": "CmRbAAAAdsT5QJMIO6suTMaofdugUTBJ2v9x3Nu7F8oxl1Lg4w-4mHOWsJGZ-E1PELiWlE5ayk0e22uABe9tPvHLkrQbXY8Hp7cge2hnlQVbY0HkI9Fd2T8USasHCTyKa3wTMo0KEhDCY1G6hK4gv2qUedfDCMxjGhRIRolzvdQ-cSTl7wma_Nwr2B9Baw",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "4624 W State St, Boise"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.6149188,
#                     "lng": -116.2839412
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.61626857989272,
#                         "lng": -116.2827009201073
#                     },
#                     "southwest": {
#                         "lat": 43.61356892010727,
#                         "lng": -116.2854005798928
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "94659697197e48daedd43bbf53d68e40e1baf476",
#             "name": "Panda Express",
#             "opening_hours": {
#                 "open_now": true,
#                 "weekday_text": []
#             },
#             "photos": [
#                 {
#                     "height": 1152,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105500837546358773070/photos\">George Gomez</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA1JwDzPtyATPyFAf4GJivtgskzsSe7lj7fT3nkPmPO_zy7GSQkpIMJuww_8d4W6C_-JN_zheeAZgFxjtTar5LqgT-dPEJjOId1Wux7toJFlqWc2BYEPM0d6jwZ37zwmjWEhDKP4e9IiANwsxF-qskg7s9GhT2zIwZRO6PdXLqz3BmSLEvQnYL1w",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJbdZEMQ1WrlQRcVfVf-Hl8g8",
#             "price_level": 1,
#             "rating": 3.9,
#             "reference": "CmRbAAAAY8_80hRfCIOJVycY9pXmf3EP5oWVNA7qu3NxJIFtPukJnrz3VBuA6nunvTTRUrTbKbLI0XHTwg6J00bK0WSsfLkw8QWhNDlXMMWWeiAAAP8bK6oL_Bq9YwnM_T89bq0xEhDS13IFKvW5Lznzm2GQoGVxGhTveqsoE_YbS40w-JOeBlyibyHYFw",
#             "scope": "GOOGLE",
#             "types": [
#                 "meal_takeaway",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "1124 N Milwaukee St, Boise"
#         }
#     ],
#     "status": "OK"
# }

# %%
# Print the name and address of the first restaurant that appears
print(places_data["results"][0]["name"])
print(places_data["results"][0]["vicinity"])
# Out:
# China Grand Buffet
# 10498 W Fairview Ave, Boise
